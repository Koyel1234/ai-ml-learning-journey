# %%
# !pip install langchian chromadb openai tiktoken pypdf langchain_openai langchain_community

# %%
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma # FAISS, Pinecone, Weaviate

# %%
from langchain.schema import Document

# create Langchain documents for IPL players

doc1 = Document(
    page_content = "Virat Kohli is one of the most successful and consistent batsman in IPL history, known for his aggressive batting style.",
    metada = {'team': "Royal Challengers Bangalore"}
)

# generate 4 more document (doc2 to doc5) like above by ChatGPT
# doc2 =

# %%
doc = [doc1, doc2, doc3, doc4, doc5]

# %%
vector_store = Chroma(
    embedding_function = OpenAIEmbeddings(), # converting docs to embeddings
    persist_directory = 'chroma.db', #.sqklite3 file will be created
    collection_name = 'sample'
)

# %%
# add documents
vector_store.add_documents(docs) # unique ids will be assigned by default, we can pass our own id

# %%
# view documents
vector_store.get(include=['embeddings', 'documents', 'metadata'])

# %%
# search documents
vector_store.similarity_search(
    query='who among these are a bowler?',
    k=2 # number of similar objects to show in output
)

# %%
# search documents
vector_store.similarity_search(
    query='who among these are a bowler?',
    k=1 # number of similar objects to show in output
)

# %%
# search with similarity score
# will show similarity score as well, the low the score, the more similar
vector_store.similarity_search_with_score(
    query='who among these are a bowler?',
    k=2 # number of similar objects to show in output
)

# %%
# search with similarity score
vector_store.similarity_search_with_score(
    query="",
    filter = {'team': 'Chennai Super Kings'} # filtering based on metadata
)

# %%
# update documents
# generate a new docuemnt about Virat Kohli in earlier format
# updated_doc1 = 

vector_store.update_document(document_id = '', document=updated_doc1) # in document_id write id of document related to Virat kohli from above

# %%
# view documents # doc relatrd to Virat kohli is updated
vector_store.get(include=['embeddings', 'documents', 'metadata'])

# %%
# delete documents
vector_store.delete(ids=['']) # put id(s) of documents want to delete # for 1 also its list

# %%
# view documents # see deleted doc is not present 
vector_store.get(include=['embeddings', 'documents', 'metadata'])

# %%
# implement same above codes for FAISS/Pinecone or any other vector db/vector store
