# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ## Univarite Analysis
#
# Analysis on single feature.

# %%
df.loc[df['species'] == 'setosa']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df_setosa = df.loc[df['species'] == 'setosa']
df_virginica = df.loc[df['species'] == 'virginica']
df_versicolor = df.loc[df['species'] == 'versicolor']

# %%
plt.plot(df_setosa['petal_length'], np.zeros_like(df_setosa['petal_length']), 'o')
plt.plot(df_virginica['petal_length'], np.zeros_like(df_virginica['petal_length']), 'o')
plt.plot(df_versicolor['petal_length'], np.zeros_like(df_versicolor['petal_length']), 'o')
plt.xlabel('Petal Length')
plt.show() # as not using plt.show() after each plot we will get overlapping graph what we want here , all three in same graph

# %% [markdown]
# ## Bivariate Analysis
#  Analysis using two features.

# %%
sns.FacetGrid(df, hue = 'species', height=5).map(plt.scatter, "sepal_length", "sepal_width").add_legend()
plt.show()

# %% [markdown]
# ## Multivariate Analysis
# Analysis considering more than two feature. We can use pairplot.

# %%
sns.pairplot(df, hue = "species", height=3)
