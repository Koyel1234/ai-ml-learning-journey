# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AutoReg

# %%
# import data
df = pd.read_csv('../datasets/daily-min-temperatures.csv', index_col=0)
print('Shape of data \t:', df.shape)
display(df.head())
# Out:
# Shape of data 	: (3650, 1)
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
X = df.values
X
# Out:
# array([[20.7],
#        [17.9],
#        [18.8],
#        ...,
#        [13.5],
#        [15.7],
#        [13. ]])

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>
