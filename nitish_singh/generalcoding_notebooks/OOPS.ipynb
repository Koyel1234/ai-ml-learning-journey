# %% [markdown]
# # OOPS

# %%
# bad way of defining class
# if attributes are not fixed, any no of attributes can be made by developper
# which is very bad idea of class
class Car:
    pass

# %%
car1 = Car()

# %%
car1

# %%
car1.windows = 5
car1.doors = 4

# %%
print(car1.windows)
# Out:
# 5

# %%
car2 = Car()

# %%
car2.windows = 3
car2.doors = 2

# %%
car2.windows
# Out:
# 3

# %%
car2.enginetype = "petrol"

# %%
car2.enginetype
# Out:
# 'petrol'

# %%
dir(car1) # inbuilt methods of class, # __init__ is constructor : constructor is function in order initilize properties of class
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors',
#  'windows']

# %%
# correct way

class Car:
    def __init__(self, window, door, enginetype): # self is directing to particular object where we are calling class
        self.windows = window
        self.doors = door
        self.enginetype = enginetype

    def self_driving(self):
        return "This is a {} car.".format(self.enginetype)

# %%
car1 = Car(4,5,"petrol")

# %%
car2 = Car(3,4,"diesel")

# %%
print(car1.windows)
# Out:
# 4

# %%
print(car2.doors)
# Out:
# 4

# %%
print(car2.enginetype)
# Out:
# diesel

# %%
car1.self_driving()
# Out:
# 'This is a petrol car.'

# %% [markdown]
# # Python Exception Handling

# %%
# interview qsn : error vs exception

# %%
a=10 # successfully

# %%
a=b # error : i am using one variable which is not already defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
try: 
    ## code block where exception can occur
    a=b
except: # highest exception class is 'Exception' itself
    print('Some problem may have occured')
# Out:
# Some problem may have occured

# %%
try: 
    ## code block where exception can occur
    a=b
except Exception as ex: # highest exception class is 'Exception' itself
    print(ex)
# Out:
# name 'b' is not defined

# %%
try: 
    ## code block where exception can occur
    a=b
except Exception as ex: # highest exception class is 'Exception' itself
    print(ex.args)
    print(ex.traceback)
    # NameError is getting of Exception class
# Out:
# ("name 'b' is not defined",)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 3
#       1 try:
#       2     ## code block where exception can occur
# ----> 3     a=b
#       4 except Exception as ex: # highest exception class is 'Exception' itself
#
# NameError: name 'b' is not defined
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 6
#       4 except Exception as ex: # highest exception class is 'Exception' itself
#       5     print(ex.args)
# ----> 6     print(ex.traceback)
#
# AttributeError: 'NameError' object has no attribute 'traceback'

# %%
try: 
    ## code block where exception can occur
    a=b
except NameError as ex1: # this is python's own exception, in gcp we used, we had to import one class for exception, hv to check from travelforecasting cloud func codes, that exception was not from python's exception class
    print("The user have not defined the variable.")
except Exception as ex: # highest exception class is 'Exception' itself
    print(ex)
    # NameError is getting of Exception class
# Out:
# The user have not defined the variable.

# %%
try: 
    ## code block where exception can occur
    a=1
    b="S"
    c = a+b
except NameError as ex1:
    print("The user have not defined the variable.")
except Exception as ex:
    print(ex)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
a=1
b="S"
c = a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 3
#       1 a=1
#       2 b="S"
# ----> 3 c = a+b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try: 
    ## code block where exception can occur
    a=1
    b="S"
    c = a+b
except NameError:
    print("The user have not defined the variable.")
except TypeError:
    print("Try to make the datatype similar.")
except Exception as ex:
    print(ex)
# Out:
# Try to make the datatype similar.

# %%
try: 
    ## code block where exception can occur
    a=int(input("Enter the number 1 "))
    b=int(input("Enter the number 1 "))
    c = a/b
    d=a*b
    e=a+b
    print(c)
    print(d)
    print(e)
except NameError:
    print("The user have not defined the variable.")
except TypeError:
    print("Try to make the datatype similar.")
except Exception as ex:
    print(ex)
# Out:
# Enter the number 1  12
# Enter the number 1  0
# division by zero

# %%
12/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 12/0
#
# ZeroDivisionError: division by zero

# %%
try: 
    ## code block where exception can occur
    a=int(input("Enter the number 1 "))
    b=int(input("Enter the number 1 "))
    c = a/b
    d=a*b
    e=a+b
    print(c)
    print(d)
    print(e)
except NameError:
    print("The user have not defined the variable.")
except ZeroDivisionError:
    print("Please provide number greater than 0.")
except TypeError:
    print("Try to make the datatype similar.")
except Exception as ex:
    print(ex)
# Out:
# Enter the number 1  12
# Enter the number 1  0
# Please provide number greater than 0.

# %%
try: 
    ## code block where exception can occur
    a=int(input("Enter the number 1 "))
    b=int(input("Enter the number 1 "))
    c = a/b
    d=a*b
    e=a+b
except NameError:
    print("The user have not defined the variable.")
except ZeroDivisionError:
    print("Please provide number greater than 0.")
except TypeError:
    print("Try to make the datatype similar.")
except Exception as ex:
    print(ex)
else:
    print(c)
    print(d)
    print(e)
# Out:
# Enter the number 1  12
# Enter the number 1  4
# 3.0
# 48
# 16

# %%
## try else
try: 
    ## code block where exception can occur
    a=int(input("Enter the number 1 "))
    b=int(input("Enter the number 1 "))
    d=a*b
    c = a/b
    e=a+b
except NameError:
    print("The user have not defined the variable.")
except ZeroDivisionError:
    print("Please provide number greater than 0.")
except TypeError:
    print("Try to make the datatype similar.")
except Exception as ex:
    print(ex)
else:
    print(d)
    print(c)
    print(e)
# if exception is getting handled then else will not execute
# Out:
# Enter the number 1  12
# Enter the number 1  0
# Please provide number greater than 0.

# %%
## try else finally
try: 
    ## code block where exception can occur
    a=int(input("Enter the number 1 "))
    b=int(input("Enter the number 1 "))
    c = a/b
except NameError:
    print("The user have not defined the variable.")
except ZeroDivisionError:
    print("Please provide number greater than 0.")
except TypeError:
    print("Try to make the datatype similar.")
except Exception as ex:
    print(ex)
else:
    print(c)
finally:
    print("The execution is done")
# else block will not be printed , but finally will always be done
# any conn to database can be done in finally bcz else or exception any one will execute so conn close can't be put there
# but finally will always be executed
# Out:
# Enter the number 1  12
# Enter the number 1  0
# Please provide number greater than 0.
# The execution is done

# %% [markdown]
# # Custom Exception

# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

class customgeneric(Error):
    pass

# %%
year = int(input("enter the year of Birth"))
age = 2024-year
try:
    if age <=30 and age >20:
        print("The age is valid. You can apply for the exams.")
    else:
        raise dobException
except dobException:
    print("The year age is not valid. You can't apply for the exam.")
# Out:
# enter the year of Birth 1989
# The year age is not valid. You can't apply for the exam.

# %% [markdown]
# # Public, Protected, Private Variables

# %%
## all class variables are public
class Car():
    def __init__(self, windows, doors, enginetype): # __init__ is constructor or initiazing method
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype

# %%
audi = Car(4,5, "Diesel")

# %%
audi # object of Car stored at particular memory loc  : 0x11e55bc0980

# %%
dir(audi)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors',
#  'enginetype',
#  'windows']

# %%
audi.windows
# Out:
# 4

# %%
audi.windows = 5
audi.windows
# Out:
# 5

# %%
## all class variables are protected
## overriding functionality will be available in subclass only
class Car1():
    def __init__(self, windows, doors, enginetype): # __init__ is constructor or initiazing method
        self._windows = windows
        self._doors = doors
        self._enginetype = enginetype

# %%
audi1 = Car1(4,4,"Diesel")
dir(audi1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_doors',
#  '_enginetype',
#  '_windows']

# %%
class Truck(Car):
    def __init__(self, windows, doors, enginetype, horsepower):
        super().__init__(windows, doors, enginetype)
        self.horsepower = horsepower

# %%
truck = Truck(4,4,"Diesel", 4000)
dir(truck)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors',
#  'enginetype',
#  'horsepower',
#  'windows']

# %%
class Truck1(Car1):
    def __init__(self, windows, doors, enginetype, horsepower):
        super().__init__(windows, doors, enginetype)
        self.horsepower = horsepower 

truck1 = Truck1(4,4,"Diesel", 4000)
dir(truck1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_doors',
#  '_enginetype',
#  '_windows',
#  'horsepower']

# %%
truck1._doors = 5
truck1._doors
# Out:
# 5

# %%
print(audi1._doors)
audi1._doors = 5
print(audi1._doors)
# Out:
# 4
# 5

# %%
class Car2():
    def __init__(self, windows, doors, enginetype): # __init__ is constructor or initiazing method
        self.__windows = windows
        self.__doors = doors
        self.__enginetype = enginetype

audi2 = Car2(4,4,"Diesel")
dir(audi2)
# Out:
# ['_Car2__doors',
#  '_Car2__enginetype',
#  '_Car2__windows',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %% [markdown]
# In Python, public, protected and private variables are just indication of its role. It will never restrict from overriding. Its better in c# or java.

# %% [markdown]
# # Inheritance

# %%
# all the class variables are public
## car blueprint
class Car():
    def __init__(self, windows, doors, enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype

    def drive(self):
        print("The person drive the car")

# %%
car = Car(4,5, "Diesel")

# %%
car.windows
# Out:
# 4

# %%
car.drive()
# Out:
# The person drive the car

# %%
class audi(Car):
    def __init__(self, windows, doors, enginetype, enableai):
        super().__init__(windows, doors, enginetype)
        self.enableai = enableai

    def selfdriving(self):
        print("Audi supports self driving.")

# %%
audiQ7 = audi(5,5,"diesel", True)

# %%
dir(audiQ7)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors',
#  'drive',
#  'enableai',
#  'enginetype',
#  'selfdriving',
#  'windows']

# %%
audiQ7.windows
# Out:
# 5

# %%
audiQ7.doors
# Out:
# 5

# %%
audiQ7.enableai
# Out:
# True

# %%
audiQ7.drive()
# Out:
# The person drive the car

# %%
audiQ7.selfdriving()
# Out:
# Audi supports self driving.

# %% [markdown]
# # Magic Methods in Classes

# %%
class Car():
    def __init__(self, windows, doors, enginetype): # initilization constructor : __init__
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype

    def drive(self): # drive is public method
        print("The person drive the car")

# %%
c = Car(4,5,"Diesel")

# %%
c # object at memory loc : 0x11e55bc2c00

# %%
dir(c) # all attributes here are called magic method
# this dir() is calling __str__ magic method
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors',
#  'drive',
#  'enginetype',
#  'windows']

# %%
print(c.__sizeof__())
# Out:
# 16

# %%
class Car():
    
    def __init__(self, windows, doors, enginetype): # initilization constructor : __init__
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype

    def __str__(self): # __str__ should return , not print()
        return "The object has been initialized."

    def __sizeof__(self):
        return "this displays size of object."
        
    def drive(self): # drive is public method
        print("The person drive the car")

car=Car(4,5,"Diesel")
print(car) # only when printing, then will get new line
car
# Out:
# The object has been initialized.

# %%
print(car.__sizeof__())
# Out:
# this displays size of object.

# %%
class Car():
    def __new__(self, windows, doors, enginetype): # __new__ should be before __init__
        print("The object has started getting initialized")
    def __init__(self, windows, doors, enginetype): # initilization constructor : __init__
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype

    def __str__(self): # __str__ should return , not print()
        return "The object has been initialized."

    def __sizeof__(self):
        return "this displays size of object."
        
    def drive(self): # drive is public method
        print("The person drive the car")

# %%
car=Car(4,5,"Diesel")
# print(car) # only when printing, then will get new line
car # with __new__, __str__ will not work, it will not show memory loc
# Out:
# The object has started getting initialized

# %% [markdown]
# # Python Assert
#
# Python provides the assert statement to check if a given logical expression is True or False. Python execution proceeds only if the expression is True and raises AssertioError when it is False. The folllowing code shows the usage of the assert statement.

# %%
num=10
assert num>=10 # not raising AssertionError as this statement/logic is True

# %%
assert num>10 # raising AssertionError as this statement/logic is False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[207], line 1
# ----> 1 assert num>10
#
# AssertionError:

# %%
try:
    num=int(input('Enter the number'))
    assert num%2==0
    print('The number is even.')
except AssertionError:
    print("Please enter even number")
# Out:
# Enter the number 12
# The number is even.

# %%
try:
    num=int(input('Enter the number'))
    assert num%2==0
    print('The number is even.')
except AssertionError:
    print("Please enter even number")
# Out:
# Enter the number 7
# Please enter even number

# %% [markdown]
# # Python Generator vs Iterator

# %%
# iterable
lst = [1,2,3,4]
for i in lst:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
## iterator
iterable = iter(lst)

# %%
# we can iterate
for i in iterable:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
type(iterable)
# Out:
# list_iterator

# %%
iterable1 = iter(lst)
print(next(iterable1))
print(next(iterable1))
print(next(iterable1))
print(next(iterable1))
print(next(iterable1))
# Out:
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[222], line 6
#       4 print(next(iterable1))
#       5 print(next(iterable1))
# ----> 6 print(next(iterable1))
#
# StopIteration:

# %%
try:
    next(iterable1)
except StopIteration:
    print("the Iterator is empty")
# Out:
# the Iterator is empty

# %%
### Generator
def square(n):
    for i in range(n):
        return i**2

# %%
square(3)
# Out:
# 0

# %%
def square(n):
    for i in range(n):
        yield i**2

# %%
square(3)
# Out:
# <generator object square at 0x0000011E569B8EE0>

# %%
for i in square(3):
    print(i)
# Out:
# 0
# 1
# 4

# %%
a = square(3)
print(next(a))
print(next(a))
print(next(a))
print(next(a))
# Out:
# 0
# 1
# 4
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[238], line 5
#       3 print(next(a))
#       4 print(next(a))
# ----> 5 print(next(a))
#
# StopIteration:

# %% [markdown]
# ### Difference : Iterator vs Generator
# 1. To create iterator we use iter() function and to create generator we use function along with yield keyword.
# 2. Generator uses yield keyword. It saves the local variable value
# 3. Usually Generator in Python helps us to write fast and compact code.
# 4. Python iterator much more mery efficient.

# %%
import types, collections

# %%
issubclass(types.GeneratorType, collections.abc.Iterator)
# Out:
# True

# %% [markdown]
# # Decorators

# %%
## function copy
## closures
## decorators

# %%
def welcome():
    return "welcome to Krish Naik Youtube Channel"

# %%
wel = welcome()  # function copy
del welcome

# %%
wel
# Out:
# 'welcome to Krish Naik Youtube Channel'

# %%
wel = welcome()
del welcome # welcome function got deleted by del keyword
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[275], line 1
# ----> 1 wel = welcome()
#       2 del welcome
#
# NameError: name 'welcome' is not defined

# %%
## closures
def main_welcome():
    msg = "Hello Everyone"
    def sub_welcome_class():
        print("Welcome.")
        print(msg)
        print("Good Bye")
    return sub_welcome_class()

# %%
main_welcome()
# Out:
# Welcome.
# Hello Everyone
# Good Bye

# %%
def main_welcome():
    msg = "Hello Everyone"
    def sub_welcome_class():
        print("Welcome.")
        print(msg)
        print("Good Bye")
    sub_welcome_class()

main_welcome()
# Out:
# Welcome.
# Hello Everyone
# Good Bye

# %%
def main_welcome(msg):
    def sub_welcome_class():
        print("Welcome.")
        print(msg)
        print("Good Bye")
    sub_welcome_class()

main_welcome("Hello Everyone")
# Out:
# Welcome.
# Hello Everyone
# Good Bye

# %%
def main_welcome(func):
    def sub_welcome_class():
        print("Welcome.")
        func("This is within print function.")
        print("Good Bye")
    return sub_welcome_class()

main_welcome(print)
# Out:
# Welcome.
# This is within print function.
# Good Bye

# %%
# initial decorator - function passed in function instead of variables

# %%
def main_welcome(func):
    def sub_welcome_class():
        print("Welcome.")
        print(func([1,2,3,4,5]))
        print("Good Bye")
    return sub_welcome_class()

main_welcome(len)
# Out:
# Welcome.
# 5
# Good Bye

# %%
def channel_name():
    print("This is channel_name function calling.")

def main_welcome(func):
    def sub_welcome_class():
        print("Welcome.")
        func()
        print("Good Bye")
    return sub_welcome_class()

main_welcome(channel_name)
# Out:
# Welcome.
# This is channel_name function calling.
# Good Bye

# %%
def main_welcome(func):
    def sub_welcome_class():
        print("Welcome new func.")
        func()
        print("Good Bye new func")
    return sub_welcome_class()
    
@main_welcome
def channel_name():
    print("This is channel_name function calling.") 
# no need to call main_welcome func
# Out:
# Welcome new func.
# This is channel_name function calling.
# Good Bye new func

# %%
def hello():
    print("Hello World")
hello()
# Out:
# Hello World

# %%
def greet(fx):
    def mfx(*args, **kwargs):
        print("Good Morning!")
        fx(*args, **kwargs)
        print("Thanks for using this function.")
    return mfx

@greet
def add(a,b):
    print(a+b)

@greet
def hello():
    print("Hello World")

# %%
hello()
# Out:
# Good Morning!
# Hello World
# Thanks for using this function.

# %%
greet(hello())
# Out:
# Good Morning!
# Hello World
# Thanks for using this function.
# <function __main__.greet.<locals>.mfx()>

# %%
greet(hello)()
# Out:
# Good Morning!
# Good Morning!
# Hello World
# Thanks for using this function.
# Thanks for using this function.

# %%
add(2,3)
# Out:
# Good Morning!
# 5
# Thanks for using this function.

# %% [markdown]
# # Constructor

# %%
class Person:
    name = "Harry"
    occ = "Developper"

    def info(self):
        print(f"{self.name} is a {self.occ}")

person = Person()
print(person.name, person.occ)
person.info()
# Out:
# Harry Developper
# Harry is a Developper

# %%
person.name = "Divya"
person.occ = "HR"
person.info()
# Out:
# Divya is a HR

# %%
class Person:
    def __init__(self): # dunder method init, inbuilt methods of class which we can override according to our wish
        self.name = "Harry"
        self.occ = "Developper"

    def info(self):
        print(f"{self.name} is a {self.occ}")

person = Person()
print(person.name, person.occ)
person.info()
# Out:
# Harry Developper
# Harry is a Developper

# %%
class Person:
    def __init__(self): # default constructor : taking no arguments
        print("I am a person.")

Person()
# Out:
# I am a person.

# %% [markdown]
# # Destructor

# %% [markdown]
# # Generator

# %%
def my_generator():
    for i in range(5):
        yield i

gen = my_generator()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 0
# 1
# 2

# %%
for j in gen:
    print(j)
# Out:
# 3
# 4

# %% [markdown]
# # Class Methods and Class Variables

# %%
class Car:
    base_price = 10000 # class_variables
    def __init__(self, windows, doors, power):
        self.windows = windows
        self.doors = doors
        self.power = power
    def what_base_price(self):
        print("The base price is {}".format(self.base_price))

# %%
car1 = Car(4,5,2000)
car1.base_price # access class_variable by making object
# Out:
# 10000

# %%
Car.base_price # access class_variable directly
# Out:
# 10000

# %%
class Car1:
    base_price = 10000 # class_variables
    def __init__(self, windows, doors, power):
        self.windows = windows
        self.doors = doors
        self.power = power
    def what_base_price(self):
        print("The base price is {}".format(self.base_price))
    @classmethod
    def revise_base_price(cls, inflation):
        cls.base_price = cls.base_price + (cls.base_price*inflation)

# %%
car1 = Car1(4,5,2000)

# %%
car1.base_price
# Out:
# 10000

# %%
car1.revise_base_price(0.1)

# %%
car1.base_price
# Out:
# 11000.0

# %%
Car1.base_price
# Out:
# 11000.0

# %%
car2 = Car1(5,6,7000)
car2.base_price
# Out:
# 11000.0

# %%
# to update class variable, use classmethod directly on class , then create object
class Car2:
    base_price = 10000 # class_variables
    def __init__(self, windows, doors, power):
        self.windows = windows
        self.doors = doors
        self.power = power
    def what_base_price(self):
        print("The base price is {}".format(self.base_price))
    @classmethod
    def revise_base_price(cls, inflation): # cls refers to class itself 
        cls.base_price = cls.base_price + (cls.base_price*inflation)
print(Car2.base_price)
Car2.revise_base_price(0.2)
print(Car2.base_price)
car3 = Car2(4,5,2000)
print(car3.base_price)
# Out:
# 10000
# 12000.0
# 12000.0

# %% [markdown]
# # Static Method

# %%
import datetime
now = datetime.datetime.now()
print(now.year)
print(type(now.year))
# Out:
# 2024
# <class 'int'>

# %%
class Car3:
    base_price = 10000 # class_variables
    def __init__(self, windows, doors, power):
        self.windows = windows
        self.doors = doors
        self.power = power
    def what_base_price(self):
        print("The base price is {}".format(self.base_price))
    @classmethod
    def revise_base_price(cls, inflation): # cls refers to class itself 
        cls.base_price = cls.base_price + (cls.base_price*inflation)
    @staticmethod
    def check_year(): # not needed: self (instance parameter), cls (class parameter)
        if now.year == 2024:
            return True
        else:
            return False

# %%
Car3.check_year() # static method is the first thing which will be initialized in class, before init also
# Out:
# True

# %%
car1 = Car3(4,5,2000)

# %%
if(car1.check_year()):
    pass
else:
    Car3.revise_base_price(0.1)

# %%
Car3.base_price
# Out:
# 10000

# %% [markdown]
# # Multiple Inheritance

# %%
class A:
    def method1(self):
        print("Class method 'A' is called.")

# %%
class B(A):
    def method1(self):
        print("Class method 'B' is called.")
    def method2(self):
        print("Class method 'B' method2 is called.")

# %%
class C(A):
    def method1(self):
        print("Class method 'C' is called.")

# %%
class D(B,C):
    def method1(self):
        print("Class method 'D' is called.")

# %%
d = D()

# %%
d.method1()
# Out:
# Class method 'D' is called.

# %%
d.method2()
# Out:
# Class method 'B' method2 is called.

# %%
B.method1(d)
# Out:
# Class method 'B' is called.

# %%
A.method1(d)
# Out:
# Class method 'A' is called.

# %%
class E(B,C):
    def method1(self):
        print("Class method 'E' is called.")
        C.method1(self)
        B.method1(self)
        A.method1(self)

# %%
e = E()

# %%
e.method1()
# Out:
# Class method 'E' is called.
# Class method 'C' is called.
# Class method 'B' is called.
# Class method 'A' is called.

# %% [markdown]
# # OOPS From Gen AI Course
#
# Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allows for modeling real-world scenarios using classes and objects. This lesson covers the basics of creating classes and objects, including instance variables and methods.

# %%
## a class is blueprint for creating objects, attributes, methods
class Car:
    pass

# %%
audi = Car()
bmw = Car()

# %%
print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)

# %%
print(bmw)

# %%
audi.windows = 4
print(audi.windows)
# Out:
# 4

# %%
tata = Car()
tata.doors = 3
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 3
#       1 tata = Car()
#       2 tata.doors = 3
# ----> 3 print(tata.windows)
#
# AttributeError: 'Car' object has no attribute 'windows'

# %%
dir(tata) # inbuild methods
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
### instance variable and Methods
# self is used to access instance variables 
class Dog:
    # constructor
    def __init__(self, name, age): # name, age are parameters
        self.name = name
        self.age = age

# create objects
dog1 = Dog("Buddy", 3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Buddy
# 3

# %%
dog2 = Dog("Lucy", 4)
print(dog2.name)
print(dog2.age)
# Out:
# Lucy
# 4

# %%
# class with instance method
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        print(f"{self.name} says woof")

# %%
dog1 = Dog("Buddy", 3)
dog1.bark()
# Out:
# Buddy says woof

# %%
dog2 = Dog("Lucy", 3)
dog2.bark()
# Out:
# Lucy says woof

# %%
## modelling a Bank Account
## Define class for bank account
class BankAccount:
    def __init__(self, owner, balance=0):
        # instance variables
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} is deposited. New balance is {self.balance}.")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds!")
        else:
            self.balance -= amount
            print(f"{amount} is withdrawn. New blance is {self.balance}")

    def get_balance(self):
        return self.balance

# %%
## create an account
account = BankAccount("Koyel", 5000)
print(account.balance)
# Out:
# 5000

# %%
account.deposit(100)
# Out:
# 100 is deposited. New balance is 5100.

# %%
account.withdraw(300)
# Out:
# 300 is withdrawn. New blance is 4800

# %%
account.get_balance()
# Out:
# 4800

# %% [markdown]
# ### conclusion
#
# Object-Oriented Programming (OOP) allows you to model real-world scenarios using classes and objects. In this lesson, you learned how to create classes and objects, define instance variables and methods, and we use them to perform various operations. Understanding these concepts is fundamental to writing effective and maintainable Python code.

# %% [markdown]
# # Inheritance
#
# Inheritance is a fundamental concept in Object-Oriented Programming (OOP) that allows a class to inherit attributes and methods from another class. this lesson covers single inheritance and multiple inheritance, demonstrating how to create and use them in Python.

# %%
# inheritance - Single Inheritance
## Parent Class
class Car:
    def __init__(self, windows, doors, enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype

    def drive(self):
        print(f"The person will drive the {self.enginetype} car.")# enginetype is attribute to this clss, self.engitype is instance variable

# %%
car1 = Car(4,5, "Petrol")
car1.drive()
# Out:
# The person will drive the Petrol car.

# %%
class Tesla(Car):
    def __init__(self, windows, doors, enginetype, is_selfdriving):
        super().__init__(windows, doors, enginetype)
        # we'll also be able to inhetrit drive method
        self.is_selfdriving = is_selfdriving

    def selfdriving(self):
        print(f"Tesla supports self driving : {self.is_selfdriving}")

# %%
tesla1 = Tesla(4,5,"Electric", True)
tesla1.drive()
tesla1.selfdriving()
# Out:
# The person will drive the Electric car.
# Tesla supports self driving : True

# %%
## Multiple Inheritance
## when a class inherits from more than one base class
## Base Class - 1
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print("Subclasses must implement this method")

## Base Class - 2
class Pet:
    def __init__(self, owner):
        self.owner = owner


## Derived class
class Dog(Animal, Pet):
    def __init__(self, name, owner):
        Animal.__init__(self, name)
        Pet.__init__(self, owner)

    def speak(self):
        return f"{self.name} says woof"

# %%
## create object
dog = Dog("Buddy", "Koyel")
print(dog.speak()) # methods will be overridden if it is defined different in derived class
print(f"owner :{dog.owner}")
# Out:
# Buddy says woof
# owner :Koyel

# %% [markdown]
# # Polymorphism
# Polymorphism is a core concept in Object -Oriented Programming (OOP) that allows objects of different classes to be treated as objects of a common superclass. It provides a way to perform a single action in different form. Polymorphism is typically achieved through method overriding and interfaces.

# %% [markdown]
# # Method Overriding
# Method overriding allows a child class to procide a specific implementtaion of a method that is already defined in its parent class

# %%
class Animal:
    def speak(self):
        return "Sound of the animal"

## Derived Class 1
class Dog(Animal):
    def speak(self):
        return "Woof!"

## Derived class 2
class Cat(Animal):
    def speak(self):
        return "Meow!"

## funtion that demonstrates polymorphism
def animal_speak(animal_name):
    print(animal_name.speak())

dog = Dog()
cat=Cat()
print(dog.speak())
print(cat.speak())
animal_speak(dog) # using object of class Dog as attribute of animal_speak class
# Out:
# Woof!
# Meow!
# Woof!

# %%
## Polymorphism with function and methods
class Shape:
    def area(self):
        return "The area of the figure"

## Derived class 1
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width*self.height

## Derived Class 2
class Circle(Shape):
    def __init__(self, radious):
        self.radious = radious

    def area(self):
        return 3.14*self.radious*self.radious


## function that demonstrates polymorphism
def print_area(shape): # shape is attributes, here it is not class Shape
    print(f"The area is {shape.area()}")

rectangle = Rectangle(4,5)
circle = Circle(3)

print_area(rectangle)
print_area(circle)
# Out:
# The area is 20
# The area is 28.259999999999998

# %% [markdown]
# # Polymorphism with Abstract Base Classes
# Abstract Base Classes (ABCs) are used to define common methods for a group of related objects. They can enforce that derived classes implement particular methods, promoting consistency across different implementations.

# %%
from abc import ABC, abstractmethod

## Define an abstract class
class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

## Derived class 1
class Car(Vehicle):
    def start_engine(self):
        return "Car engine started"

## Derived class 2
class Motorcycle(Vehicle):
    def start_engine(self):
        return "Motorcycle engine started"

def start_vehicle(vehicle):
    print(vehicle.start_engine())

## create objects of car and motorcycle

car = Car()
motorcycle = Motorcycle()

start_vehicle(car)
start_vehicle(motorcycle)
# Out:
# Car engine started
# Motorcycle engine started

# %% [markdown]
# ### Polymorphism
# Polymorphism is a powerful feature of OOP that allows for flexibility and integration in code design. It enables a single function to different classes, each with its own implementation of a method. By understanding and applying polymorphism, you can create more extensible and maintainable object-oriented programs.

# %% [markdown]
# # Encapsulation and Abstraction
# Encapsulation and abstraction are two fundamental principles of Object-Oriented Programming (OOP) that help in designing robust, maintainable, and reusable code. Encapsulation involves bundling data and methods that operate on the data within a single unit, while abstraction involves hiding complex implementation details and exposing only the necessary features.
#
# ### Encapsulation
# Encapsulation is the concept of wrapping data (variables) and methods (functions) together as a single unit. It restricts direct access to some of the object's components, which is a means of preventing accidental interface and misuse of the data.

# %% [markdown]
# # Public, Protected, Private variables or access modifiers

# %%
class Person:
    def __init__(self, name, age):
        self.name = name # public variable
        self.age = age # public variable

def get_name(person):
    return person.name

person = Person("Koyel", 25)
print(person.name)
get_name(person)
# Out:
# Koyel
# 'Koyel'

# %%
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
class Person:
    def __init__(self, name, age, gender):
        self.__name = name # private variable
        self.__age = age # private variable
        self.gender = gender # public variable

# %%
person = Person("Koyel", 25, "Female")
dir(person)
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gender']

# %%
print(person.name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 print(person.name)
#
# AttributeError: 'Person' object has no attribute 'name'

# %%
def get_name(person):
    return person.__name

get_name(person)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[115], line 4
#       1 def get_name(person):
#       2     return person.__name
# ----> 4 get_name(person)
#
# Cell In[115], line 2, in get_name(person)
#       1 def get_name(person):
# ----> 2     return person.__name
#
# AttributeError: 'Person' object has no attribute '__name'

# %%
def get_name(person):
    return person._Person__name

get_name(person)
# Out:
# 'Koyel'

# %%
class Person:
    def __init__(self, name, age, gender):
        self._name = name # protected variable
        self._age = age # protected variable
        self.gender = gender # public variable

# protected variables can be accessed from derived class
class Employee(Person):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)

def get_name(person):
    return person._name


employee = Employee("Koyel", 25, "Female")
dir(employee)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_age',
#  '_name',
#  'gender']

# %%
print(employee._name)
get_name(employee)
# Out:
# Koyel
# 'Koyel'

# %%
## Encapsulation with Getter and Setter Methods
class Person:
    def __init__(self, name, age):
        self.__name = name ## private access modifier or variable
        self.__age = age

    ## getter method for name
    def get_name(self):
        return self.__name

    ## setter method for name
    def set_name(self, new_name):
        self.__name = new_name

    ## getter method for age
    def get_age(self):
        return self.__age

    ## setter method for age
    def set_age(self, new_age):
        if new_age > 0:
            self.__age = new_age
        else:
            print("Age cannot be negative")

# %%
person = Person("koyel", 25)

## access and modify private variables using getter and setter
print(person.get_name())
print(person.get_age())

person.set_age(35)
print(person.get_age())

person.set_age(-5)
# Out:
# koyel
# 25
# 35
# Age cannot be negative

# %% [markdown]
# # Abstraction
# Abstraction is the concept of hiding the complex implementation details and showing only necessary features of an object. This helps in reducing programming complexity and effort.

# %%
from abc import ABC, abstractmethod

## Abstract Class
class Vehicle(ABC): # inheriting abstract base class ABC
    def drive(self):
        print("The vehicle is used for driving")

    @abstractmethod
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        print("Car engine started")

def operate_vehicle(vehicle):
    vehicle.start_engine()
    vehicle.drive()

car = Car()
operate_vehicle(car)
# Out:
# Car engine started
# The vehicle is used for driving

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    # @abstractmethod
    def print_area(self):
        return 0

class Rectangle(Shape):
    type = "Rectangle"
    sides = 4
    def __init__(self):
        self.length = 6
        self.breadth = 7

    # def print_area(self):
    #     return self.length*self.breadth

# %%
rect1 = Rectangle()

# %%
rect1.print_area()
# Out:
# 0

# %%
# methods are of two types : concrete method, abstractmethod
class BankApp(ABC): # abstractclass should contain atleast one abstractmethod
    def database(self):
        print('connected to database')

    @abstractmethod
    def security(self):
        pass

class MobileApp(BankApp):
    def mobile_login(self):
        print('login into mobile')

mob = MobileApp()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[199], line 14
#      11     def mobile_login(self):
#      12         print('login into mobile')
# ---> 14 mob = MobileApp()
#
# TypeError: Can't instantiate abstract class MobileApp without an implementation for abstract method 'security'

# %%
bankapp = BankApp()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[203], line 1
# ----> 1 bankapp = BankApp()
#
# TypeError: Can't instantiate abstract class BankApp without an implementation for abstract method 'security'

# %%
class BankApp(ABC): # abstractclass should contain atleast one abstractmethod
    def database(self):
        print('connected to database')

    @abstractmethod
    def security(self):
        pass

class MobileApp(BankApp):
    def mobile_login(self):
        print('login into mobile')

    def security(self):
        print('mobile security')
        
mob = MobileApp()
mob.security()
# Out:
# mobile security

# %% [markdown]
# # Magic Methods
# Magic method in python, also known as dunder methods (double underscore methods), are special methods that start and end with double underscores. These methods enable you to define the behavious of objects for built-in operations, such as arithmetic operations, comparisons and more.
#
# Magic Methods
#
# Magic methods are predefined methods in Python that you can override to change the behaviour of your objects. Some common magic methods include:

# %%
# - __init__: Initilizes a new instance of a class
# - __str__: Returns a string representation of an object
# - __repr__: Returns an official string representation of an object
# - __getitem__: get an item froma container
# - __setitem__: Sets an item in a container

# %%
## Basic Magic methods
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

person = Person("Koyel", 34)
print(person) # <__main__.Person object at 0x00000224589F05F0> for default __str__ method

# %%
# override __str__
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name}, {self.age} years old"

    def __repr__(self):
        return f"Person(name='{self.name}', age = {self.age})"

person = Person("Koyel", 34)
print(person)
print(repr(person))
# Out:
# Koyel, 34 years old
# Person(name='Koyel', age = 34)

# %% [markdown]
# # Operator Overloading

# %%
## common operator overloading magic methods
# __add__(self, other) : Adds two objects using + operator
# __sub__(self, other) : Subtracts two objects using - operator
# __mul__(self, other) : Multiplies two objects using * operator
# __truediv__(self, other) : Divides two objects using / operator
# __eq__(self, other) : Checks if two objects are equal using == operator
# __lt__(self, other) : Checks if one object is less than another using the < operator

# %%
## mathematical operation on vectors
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return self.x + other.x, self.y+other.y
        
    def __sub__(self, other):
        return self.x - other.x, self.y-other.y
        
    def __mul__(self, other):
        return self.x * other.x, self.y*other.y
        
    def __eq__(self, other):
        return self.x == other.x, self.y==other.y
        
    def __repr__(self):
        f"Vector(x={self.x}, y={self.y})"

# %%
v1 = Vector(2,3)
v2 = Vector(4,5)

print(v1+v2) # v2 will be 'other'
print(v1-v2)
print(v1*v2)
print(v1==v2)
# Out:
# (6, 8)
# (-2, -2)
# (8, 15)
# (False, False)

# %% [markdown]
# # Polymorphism

# %%
# in-built polymorphic functions
# len() is being used for string
print(len('abcde'))
# len() is being used for list
print(len([1,2,3,4]))
# Out:
# 5
# 4

# %%
# user defined polymorphic functions
def add_values(x, y, z=0):
    return x+y+z

print(add_values(2,3))
print(add_values(2,3,4))
# Out:
# 5
# 9

# %%
# polymorphism with class methods
class India:
    def type(self):
        print("India is a developping country.")

    def language(self):
        print("Hindi is most spoken language in India.")

    def capital(self):
        print("New Delhi is capital of India.")

class USA:
    def type(self):
        print("USA is a developped country.")

    def language(self):
        print("Englih is most spoken language in USA.")

    def capital(self):
        print("Washington, D.C. is capital of USA.")

ind_obj = India()
usa_obj = USA()

for obj in [ind_obj, usa_obj]:
    obj.type()
    obj.language()
    obj.capital()
    print()
# Out:
# India is a developping country.
# Hindi is most spoken language in India.
# New Delhi is capital of India.
#
# USA is a developped country.
# Englih is most spoken language in USA.
# Washington, D.C. is capital of USA.

# %%
# polymorphism with inheritance
# Method Overriding
class Bird:
    def intro(self):
        print('There are many birds.')
    def flight(self):
        print('Most of the birds can fly some cannot.')

class Sparrow(Bird):
    def flight(self):
        print('Sparrow can fly.')

class Ostritch(Bird):
    def flight(self):
        print("Ostritch can't fly.")


bird_obj = Bird()
sparrow_obj = Sparrow()
ostritch_obj = Ostritch()

bird_obj.intro()
bird_obj.flight()
print()
sparrow_obj.intro()
sparrow_obj.flight()
print()
ostritch_obj.intro()
ostritch_obj.flight()
# Out:
# There are many birds.
# Most of the birds can fly some cannot.
#
# There are many birds.
# Sparrow can fly.
#
# There are many birds.
# Ostritch can't fly.

# %%
class Bird:
    def __init__(self, name):
        self.name = name
    def name_of_bird(self):
        print(f"This is class for {self.name}.")
    def intro(self):
        print('There are many birds.')
    def flight(self):
        print('Most of the birds can fly some cannot.')

class Sparrow(Bird):
    def __init__(self, name):
        super().__init__(name)
    def flight(self):
        print('Sparrow can fly.')

class Ostritch(Bird):
    def __init__(self, name):
        super().__init__(name)
    def flight(self):
        print("Ostritch can't fly.")


bird_obj = Bird('not a particular bird')
sparrow_obj = Sparrow('Sparrow')
ostritch_obj = Ostritch('Ostritch')

bird_obj.name_of_bird()
bird_obj.intro()
bird_obj.flight()
print()
sparrow_obj.name_of_bird()
sparrow_obj.intro()
sparrow_obj.flight()
print()
ostritch_obj.name_of_bird()
ostritch_obj.intro()
ostritch_obj.flight()
# Out:
# This is class for not a particular bird.
# There are many birds.
# Most of the birds can fly some cannot.
#
# This is class for Sparrow.
# There are many birds.
# Sparrow can fly.
#
# This is class for Ostritch.
# There are many birds.
# Ostritch can't fly.

# %%
class Bird:
    def __init__(self, name):
        self.name = name
    def name_of_bird(self):
        print(f"This is class for {self.name}.")
    def intro(self):
        print('There are many birds.')
    def flight(self):
        print('Most of the birds can fly some cannot.')

class Sparrow(Bird):
    def __init__(self, name):
        super().__init__(name)
    def flight(self):
        print('Sparrow can fly.')

class Ostritch(Bird):
    def __init__(self, name):
        super().__init__(name)
    def flight(self):
        print("Ostritch can't fly.")


def func(obj):
    obj.name_of_bird()
    obj.intro()
    obj.flight()
    print()

bird_obj = Bird('not a particular bird')
sparrow_obj = Sparrow('Sparrow')
ostritch_obj = Ostritch('Ostritch')

func(bird_obj)
func(sparrow_obj)
func(ostritch_obj)
# Out:
# This is class for not a particular bird.
# There are many birds.
# Most of the birds can fly some cannot.
#
# This is class for Sparrow.
# There are many birds.
# Sparrow can fly.
#
# This is class for Ostritch.
# There are many birds.
# Ostritch can't fly.

# %% [markdown]
# # OOPS - Code with Harry

# %%
class Employee:
    pass

harry = Employee()
rohan = Employee()

harry.fname = "harry"
harry.lname = "jackson"
harry.salary = 40000

rohan.fname = "rohan"
rohan.lname = "das"
rohan.salary = 4400

# %%
print(harry.fname)
print(harry, rohan)
# Out:
# harry
# <__main__.Employee object at 0x000002FC31122270> <__main__.Employee object at 0x000002FC23100860>

# %%
class Employee:
    increment = 1.5
    no_of_emp = 0
    def __init__(self, fname, lname, salary):
        self.fname = fname
        self.lname = lname
        self.salary = salary
        # self.increment = 2
        # self.email = fname+lname+"@gmail.com"
        Employee.no_of_emp += 1

    def increase(self):
        self.salary = self.salary + self.increment # class variable, instance variable

    @classmethod # classmethod takes class as argument, change class variables, don't need to pass self
    def change_increment(cls):
        cls.increment = 2

    @classmethod # classmethod as alternative constructor
    def from_str(cls, emp_string):
        fname, lname, salary = emp_string.split("-")
        return cls(fname, lname, salary)

    #static function don't use self or cls as argument
    @staticmethod
    def isopen(day):
        if day == 'sunday':
            return False
        else:
            return True

    @property
    def email(self):
        return self.fname+self.lname+"@gmail.com"

    @email.setter
    def email(self, given_email):
        self.email = given_email

    # dunder method
    def __add__(self, other): 
        return self.salary + other.salary

    def __repr__(self):
        return "Employee({}, {}, {})".format(self.fname, self.lname, self.salary)

    def __str__(self):
        return f"The name of employee is {self.fname}"


print(Employee.no_of_emp)
harry = Employee("harry", "jackson", 40000)
rohan = Employee("rohan", "das", 4400)
print(Employee.no_of_emp)

print(harry.fname, rohan.lname, rohan.salary)
# Out:
# 0
# 2
# harry das 4400

# %%
harry.email
# Out:
# 'harryjackson@gmail.com'

# %%
harry.lname="changed"
harry.email
# Out:
# 'harrychanged@gmail.com'

# %%
harry.email = "ff"
harry.email
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 harry.email = "ff"
#       2 harry.email
#
# Cell In[151], line 38, in Employee.email(self, given_email)
#      36 @email.setter
#      37 def email(self, given_email):
# ---> 38     self.email = given_email
#
# Cell In[151], line 38, in Employee.email(self, given_email)
#      36 @email.setter
#      37 def email(self, given_email):
# ---> 38     self.email = given_email
#
#     [... skipping similar frames: Employee.email at line 38 (1489 times)]
#
# Cell In[151], line 38, in Employee.email(self, given_email)
#      36 @email.setter
#      37 def email(self, given_email):
# ---> 38     self.email = given_email
#
# RecursionError: maximum recursion depth exceeded

# %%
print(repr(harry))
# Out:
# Employee(harry, jackson, 40000)

# %%
str(harry)
# Out:
# 'The name of employee is harry'

# %%
harry+rohan
# Out:
# 44400

# %%
harry.isopen("sunday")
# Out:
# False

# %%
Employee.isopen("monday")
# Out:
# True

# %%
harry.increase()

# %%
harry.salary
# Out:
# 40001.5

# %%
print(harry.__dict__) # to see all methods, variables of that object
# Out:
# {'fname': 'harry', 'lname': 'jackson', 'salary': 40001.5}

# %%
print(Employee.__dict__) # to see all methods, variables of that class
# Out:
# {'__module__': '__main__', 'increment': 1.5, '__init__': <function Employee.__init__ at 0x000002FC3152A700>, 'increase': <function Employee.increase at 0x000002FC3152A160>, '__dict__': <attribute '__dict__' of 'Employee' objects>, '__weakref__': <attribute '__weakref__' of 'Employee' objects>, '__doc__': None}

# %%
Employee.change_increment()

# %%
Employee.increment
# Out:
# 2

# %%
harry.increase()

# %%
harry.salary
# Out:
# 40003.5

# %%
lovish = Employee.from_str("lovish-jackson-76000")
print(lovish.fname, lovish.lname, lovish.salary)
# Out:
# lovish jackson 76000

# %%
class Programmer(Employee):
    pass

har = Programmer("har", "sd", 450)
har.salary
# Out:
# 450

# %%
class Programmer(Employee):
    def __init__(self, fname, lname, salary, proglang, exp):
        super().__init__(fname, lname, salary)
        self.proglang = proglang
        self.exp = exp

    def increase(self):
        self.salary = int(self.salary + self.increament+0.2)


har = Programmer("har", "sd", 450, "python", "5 yrs")
har.salary, har.exp
# Out:
# (450, '5 yrs')

# %%
a=6
a.__add__(7)
# Out:
# 13

# %%
print(6+7)
# Out:
# 13

# %%
a.__mul__(7)
# Out:
# 42

# %% [markdown]
# # OOPS - Campusx

# %%
# oops - object, class, abstraction,inheritance, encapsulation,polymorphism

# %%
# abstraction
from abc import ABC, abstractmethod
class BankApp(ABC):
    def database(self):
        print('connected to database')

    @abstractmethod
    def security(self):
        pass

    @abstractmethod
    def display(self):
        pass

# %%
class MobileApp(BankApp):
    def mobile_login(self):
        print('login into mobile')

    def security(self):
        print('mobile security')
        
    def display(self):
        print('mobile display')

# %%
mobile = MobileApp()

# %%
mobile.database()
# Out:
# connected to database

# %%
mobile.security()
# Out:
# mobile security

# %%
mobile.display()
# Out:
# mobile display

# %%
bank = BankApp()

# %% [markdown]
# # Decorators and Namespaces - Campussx

# %%
L = [1,2,3]
print(max(L))
def max():
    print('Hello')

print(max(L))
# Out:
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 def max():
#       4     print('Hello')
# ----> 6 print(max(L))
#
# TypeError: max() takes 0 positional arguments but 1 was given

# %%
def func():
    print('hello')

a = func
a()
# Out:
# hello

# %%
del func

# %%
func()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 func()
#
# NameError: name 'func' is not defined

# %%
a()
# Out:
# hello

# %%
def modify(func,num):
    return func(num)

def square(num):
    return num**2

modify(square,2)
# Out:
# 4

# %%
def my_decorator(func):
    def wrapper():
        print('*'*20)
        func()
        print('*'*20)
    return wrapper

def hello():
    print('hello')

a = my_decorator(hello)
a()
# Out:
# ********************
# hello
# ********************

# %%
def my_decorator(func):
    def wrapper():
        print('*'*20)
        func()
        print('*'*20)
    return wrapper

@my_decorator
def hello():
    print('hello')

hello()
# Out:
# ********************
# hello
# ********************

# %%
def outer():
    a = 5
    def inner():
        print(a)
    return inner

b = outer()
b()
# Out:
# 5

# %%
import time

def timer(func):
    def wrapper(*args):
        start = time.time()
        func(*args)
        print('time taken by', func.__name__, time.time()-start, 'secs')
    return wrapper
    
@timer
def display():
    print("hi")

@timer
def square(num):
    print(num**2)

@timer
def power(num,p):
    print(num**p)

display() 
square(2)
power(2,3)
# Out:
# hi
# time taken by display 0.0 secs
# 4
# time taken by square 0.0 secs
# 8
# time taken by power 0.0 secs

# %%
def sanity_check(data_type):
    def outer_wrapper(func):
        def inner_wrapper(*args):
            print(args)
            print(type(args))
            if type(args) == data_type:
                func(*args)
            else:
                raise TypeError('Incorrect Datatype')
        return inner_wrapper
    return outer_wrapper

@sanity_check(int)
def square(num):
    print(num**2)

square(2)
# Out:
# (2,)
# <class 'tuple'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[237], line 17
#      13 @sanity_check(int)
#      14 def square(num):
#      15     print(num**2)
# ---> 17 square(2)
#
# Cell In[237], line 9, in sanity_check.<locals>.outer_wrapper.<locals>.inner_wrapper(*args)
#       7     func(*args)
#       8 else:
# ----> 9     raise TypeError('Incorrect Datatype')
#
# TypeError: Incorrect Datatype

# %%
type((2))
# Out:
# int

# %%
# assert statement
age = 20
assert age==18, 'Wrong age'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 # assert statement
#       2 age = 20
# ----> 3 assert age==18, 'Wrong age'
#
# AssertionError: Wrong age

# %%
x = 1
assert x == 2, 'x should be 1'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 x = 1
# ----> 2 assert x == 2, 'x should be 1'
#
# AssertionError: x should be 1

# %%
def sum_list(lst:list) -> float:
    assert type(lst) == list, 'param lst must be of type list'
    assert len(lst), 'input list is empty'
    total = 0
    for item in lst:
        total += item
    return total

# %%
lst_sum = sum_list([1,2])
print(lst_sum)
# Out:
# 3

# %%
def sum_list(lst):
    # assert type(lst) == list, 'param lst must be of type list'
    # assert len(lst), 'input list is empty'
    total = 0
    for item in lst:
        total += item
    return total

# %%
sum_list({'a':2, 'b':2})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sum_list({'a':2, 'b':2})
#
# Cell In[25], line 6, in sum_list(lst)
#       4 total = 0
#       5 for item in lst:
# ----> 6     total += item
#       7 return total
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %%
def start_program(data: dict):
    assert isinstance(data, dict), 'Invalid json'
    assert data, 'No data found'
    print('Loaded successfully')
# Out:
# <>:2: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# <>:2: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# C:\Users\koyel\AppData\Local\Temp\ipykernel_10184\2925800836.py:2: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert (isinstance(data, dict), 'Invalid json')

# %%
start_program(data={'user':123})
print(__debug__)
# Out:
# Loaded successfully
# True

# %%
# python -O script.py (removes assertion check)
# python -OO script.py (removes docstrings too)

# %%
.1+.2 == .3
# Out:
# False

# %%
a:float = 0.1
b:float = 0.2
c=0.3
print(a+b)
# Out:
# 0.30000000000000004

# %%
def compare_floats(a:float, b:float, tol:float)->bool:
    absolute:float = abs(a-b)
    print(f'{a} - {b} = {a-b}')
    return absolute<tol

# %%
compare_floats(a+b,c,tol=1e-10)
# Out:
# 0.30000000000000004 - 0.3 = 5.551115123125783e-17
# True

# %%
import math
print(math.isclose(a+b, c, rel_tol=1e-10))
# Out:
# True

# %%
try:
    a=1
    b=2
    print(1+'a'==b)
except:
    print('Sorry')
# Out:
# Sorry

# %%
try:
    a = [1,1,4]
    print(min(a))
    a.upper()
    
except  AttributeError as e:
    print(e)
except Execption as e:
    print(e)

else:
    'executinh else'
# Out:
# 1
# 'list' object has no attribute 'upper'

# %%
try:
    a = [1,1,4]
    print(min(a))
    a.upper()
    
except  AttributeError as e:
    print(e)
except Execption as e:
    print(e)
finally:
    print('finally')
# Out:
# 1
# 'list' object has no attribute 'upper'
# finally

# %%
raise AttributeError('try')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 raise AttributeError('try')
#
# AttributeError: try

# %%
class Bank:
    def __init__(self,balance):
        self.balance = balance

    def withdraw(self, amount):
        if amount<0:
            raise Exception("amount can't be 0")
        if self.balance < amount:
            raise Exception('low money')
        self.balance = self.balance - amount

obj = Bank(10000)
try:
    obj.withdraw(500000)
except Exception as e:
    print(e)
else:
    print(obj.balance)
# Out:
# low money

# %%
class MyException(Exception):
    def __init__(self, message):
        print(message)

class Bank:
    def __init__(self,balance):
        self.balance = balance

    def withdraw(self, amount):
        if amount<0:
            raise MyException("amount can't be 0")
        if self.balance < amount:
            raise MyException('low money')
        self.balance = self.balance - amount

obj = Bank(10000)
try:
    obj.withdraw(500000)
except MyException as e:
    pass
else:
    print(obj.balance)
# Out:
# low money

# %%
class SecurityError(Exception):
    def __init__(self, message):
        print(message)
    def logout(self):
        print('logout')

class Google:
    def __init__(self, name, email, password, device):
        self.name = name
        self.email = email
        self.password = password
        self.device = device

    def login(self, email, password, device):
        if device != self.device:
            raise SecurityError('Loggiong out from all devices')
        if email == self.email and password == self.password:
            print('welcome')
        else:
            print('login error')


obj = Google('Koyel', 'koyel@gmail.com', '1234', 'android')

# %%
try:
    obj.login('koyel@gmail.com', '1234', 'android')
except SecurityError as e:
    e.logout()
else:
    print(obj.name)
finally:
    print('all database connections closed')
# Out:
# welcome
# Koyel
# all database connections closed

# %%
try:
    obj.login('koyel@gmail.com', '1234', 'windows')
except SecurityError as e:
    e.logout()
else:
    print(obj.name)
finally:
    print('all database connections closed')
# Out:
# Loggiong out from all devices
# logout
# all database connections closed

# %% [markdown]
# # OOB
# - Basics of OOP
# - Types of variables and methods
# - Inheritance
# - Polymorphism
# - Encapsulation
# - Abstraction
# - Interface
# - Mini-Project using OOP
# - Interview Question
#
# Requirements:
# - Python Basic knowledge
# - Functional Programming (Decorator)

# %% [markdown]
# ## Decorator

# %%
# what are names?
# name and identifier same
a=20
print(id(20))
print(id(a))
# Out:
# 140719784082456
# 140719784082456

# %%
# namespace - collection of names
a=10
b=20
c=30
d=40
e=20
# one name should tag one object at a time

# %% [markdown]
# Types of namespace:
# - built-in namespace
# - Module level/global namespace
# - Local namespace
# - Enclosed Namespace

# %%
dir() # built-in namespace
# Out:
# ['In',
#  'NamespaceMagics',
#  'Out',
#  '_',
#  '_1',
#  '_10',
#  '_2',
#  '_3',
#  '_4',
#  '_5',
#  '_6',
#  '_7',
#  '_8',
#  '_9',
#  '__',
#  '__K',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__import__',
#  '__ipywidgets',
#  '__loader__',
#  '__name__',
#  '__np',
#  '__package__',
#  '__pandas',
#  '__pd',
#  '__pyspark',
#  '__session__',
#  '__spec__',
#  '__tf',
#  '__torch',
#  '__xr',
#  '_attempt_import',
#  '_check_imported',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_jupyterlab_variableinspector_Jupyter',
#  '_jupyterlab_variableinspector_default',
#  '_jupyterlab_variableinspector_deletevariable',
#  '_jupyterlab_variableinspector_dict_list',
#  '_jupyterlab_variableinspector_displaywidget',
#  '_jupyterlab_variableinspector_getcontentof',
#  '_jupyterlab_variableinspector_getmatrixcontent',
# ...

# %%
# global namespace - namespace for module

# %%
a=50 # global a
def func1(): # global function func1
    a=10 # local a
    def func2(): # local function func2
        a=40 # enclosed a
        print('dir for func2:',dir())
    func2()
    print('dir for func1:', dir())

func1()
# Out:
# dir for func2: ['a']
# dir for func1: ['a', 'func2']

# %% [markdown]
# ## LEGB RULE (Local Enclosed Global Built-in scope)

# %%
x = 100
def outer():
    global x
    x = x+20
    y = 20 # scope of variable x in local only
    print(y)

outer()
# Out:
# 20

# %%
# x=100
def outer():
    # x=20 #non-local variable
    def inner():
        # nonlocal x
        # x=x+20
        # x=200
        print(z)
    inner()

outer()
print(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 11
#       8         print(z)
#       9     inner()
# ---> 11 outer()
#      12 print(z)
#
# Cell In[47], line 9, in outer()
#       4 def inner():
#       5     # nonlocal x
#       6     # x=x+20
#       7     # x=200
#       8     print(z)
# ----> 9 inner()
#
# Cell In[47], line 8, in outer.<locals>.inner()
#       4 def inner():
#       5     # nonlocal x
#       6     # x=x+20
#       7     # x=200
# ----> 8     print(z)
#
# NameError: name 'z' is not defined

# %%
# closure
def outer():
    print('Hello')
    def inner(): # scope of inner func is outer function only
        print('bye')
    inner()

print(outer) # outer function at memory location
# Out:
# <function outer at 0x000001CEC5798B80>

# %%
print(type(outer)) # each function is object of class function
# Out:
# <class 'function'>

# %%
outer()
# Out:
# Hello
# bye

# %%
new = outer # function aliasing
new()
outer()
# Out:
# Hello
# bye
# Hello
# bye

# %%
# function is python object
def outer():
    print('hello')

outer()
# Out:
# hello

# %%
print(type(outer))
# Out:
# <class 'function'>

# %%
# nested function
def outer():
    x = 100
    print('hello')
    def inner():
        print('bye')
        print(dir())
    print(dir())
    inner()

# outer()
print(dir(outer))
# Out:
# ['__annotations__', '__builtins__', '__call__', '__class__', '__closure__', '__code__', '__defaults__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__get__', '__getattribute__', '__getstate__', '__globals__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__kwdefaults__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__type_params__']

# %%
# aliasing
new = outer
new()
outer()
# Out:
# hello
# ['inner', 'x']
# bye
# []
# hello
# ['inner', 'x']
# bye
# []

# %%
# closures
def outer():
    def inner():
        x=200
        return x
    return inner()

outer()
# Out:
# 200

# %%
new = outer()

# %%
print(new)
# Out:
# 200

# %%
# decorators
# decorator takes other functions as input and add additional functionalities to the exixting function and returns it
# function -> decorator -> function
# decorator can modify class also

# %%
def printer():
    print("welcome!")
    print("welcome!")

printer()
# Out:
# welcome!
# welcome!

# %%
# add anoth print welcome without modifying printer function
def decor(func):
    def inner():
        func()
        # add new functionality
        print("Welcome!")
    # inner()
    return inner 

decor(printer)
# Out:
# <function __main__.decor.<locals>.inner()>

# %%
printer = decor(printer) # is now printer will have different memory location?
printer()
# Out:
# welcome!
# welcome!
# Welcome!

# %%
new_printer = decor(printer)
new_printer()
# Out:
# welcome!
# welcome!
# Welcome!
# Welcome!

# %%
# example 2
def addition():
    num1 = float(input("Enter first number:"))
    num2 = float(input("Enter second number:"))
    result = num1 + num2
    return result

# def decor(func_name): # if use this decor func which is returning result directly this is just a normal function this which is taking another function as input, 
#     # def inner():
#     result = func_name()
#     num3 = float(input("Enter third number:"))
#     result = result + num3
#     return result

# def decor(func_name): # this will return whole new function which we will get by modifying old function as a object, can use this will multiple inputs during function call
#     def inner():
#         result = func_name()
#         num3 = float(input("Enter third number:"))
#         result = result + num3
#         return result
#     return inner

val = decor(addition)
val()
# Out:
# Enter first number: 2
# Enter second number: 3
# Enter third number: 4
# 9.0

# %%
def addition(num1, num2):
    result = num1 + num2
    print(__name__)
    return result

# def decor(func_name, num1, num2, num3): # if use this decor func which is returning result directly this is just a normal function this which is taking another function as input, 
#     result = func_name(num1, num2)
#     result = result + num3
#     return result

def decor(func_name, num1, num2, num3): # this will return whole new function which we will get by modifying old function as a object, can use this will multiple inputs during function call
    def inner():
        result = func_name(num1, num2)
        result = result + num3
        print(func_name.__name__)
        return result
    return inner

# val = decor(addition)
# val()

val = decor(addition, 2,3,4)
val()
# addition(2,3)
# Out:
# __main__
# addition
# 9

# %%
# def decor(func_name): # this will return whole new function which we will get by modifying old function as a object, can use this will multiple inputs during function call
#     def inner():
#         result = func_name()
#         num3 = float(input("Enter third number:"))
#         result = result + num3
#         return result
#     return inner

def decor(func_name): # if use this decor func which is returning result directly this is just a normal function this which is taking another function as input, 
    # def inner():
    result = func_name()
    num3 = float(input("Enter third number:"))
    result = result + num3
    return result

@decor
def addition():
    num1 = float(input("Enter first number:"))
    num2 = float(input("Enter second number:"))
    result = num1 + num2
    return result



# val = decor(addition)
# val()

a = addition()
a()

# to use @decor syntax decor func shoould give a function object as output, so if decor is not giving fuction object as output @decor syntax can't be used, as in the second decor function, it is taking another function as input doing some extra work with it, returning the output not the modified versin of function as a new function
# Out:
# Enter first number: 2
# Enter second number: 3
# Enter third number: 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 28
#      21     return result
#      25 # val = decor(addition)
#      26 # val()
# ---> 28 a = addition()
#      29 a()
#
# TypeError: 'float' object is not callable

# %%
## decorator with input
# @decor
# def addition(num1, num2):
#     result = num1 + num2
#     return result

# def decor(func_name, num1, num2, num3): # if use this decor func which is returning result directly this is just a normal function this which is taking another function as input, 
#     result = func_name(num1, num2)
#     result = result + num3
#     return result

def decor(func_name, num1, num2, num3): # this will return whole new function which we will get by modifying old function as a object, can use this will multiple inputs during function call
    def inner():
        result = func_name(num1, num2)
        result = result + num3
        return result
    return inner
# @decor
def addition(num1, num2):
    result = num1 + num2
    return result
# val = decor(addition)
# val()

val = decor(addition, 2,3,4)
val()

# addition()
# Out:
# 9

# %%
# multiple decorators on one function
def decor1(func):
    def inner():
        return func().upper() # KOYEL PRAMANICK
    return inner

def decor2(func):
    def inner():
        # func()
        return func().split()
    print('w',inner())
    return inner

# @decor1
# @decor2
# def get_name():
#     first_name = input("Enter first name:") # Koyel
#     second_name = input("Enter second name:") # Pramanick
#     full_name = first_name + " " + second_name
#     return full_name

@decor2
@decor1
def get_name():
    first_name = input("Enter first name:") # Koyel
    second_name = input("Enter second name:") # Pramanick
    full_name = first_name + " " + second_name
    return full_name

# get_name = decor1(decor2(get_name))
# get_name = decor2(decor1(get_name))
print(get_name())

# decor1 - KOYEL PRAMANICK
# decor2 - ['KOYEL', 'PRAMANICK']
# Out:
# Enter first name: e
# Enter second name: t
# w ['E', 'T']
# Enter first name: t
# Enter second name: j
# ['T', 'J']

# %%
# apply same decorator on multiple functions

def decor(func):
    def inner(*args): #(0,10,5)
        for num in args[1:]:
            if num==0:
                return "cannot divide by zero"
        return func(*args)
    return inner

@decor
def div1(a, b):
    return a/b
@decor
def div2(a, b, c):
    return a/b/c

print(div2(10,1,0))
print(div1(7,8))
# Out:
# cannot divide by zero
# 0.875

# %%
# what are callable objects - callable(python_object) - True, False, __call__majic method is implemented there
x = 100

def add(a, b):
    return a+b

callable(x)
# Out:
# False

# %%
add(10,20)
# Out:
# 30

# %%
add.__call__(10,20)
# Out:
# 30

# %%
class Add(object):
    def __init__(self,a, b):
        self.a = a
        self.b = b

    def __call__(self): # make class object callable
        print("hello")
        print(self.a+self.b)
    

a1 = Add(10, 20)
a1()
# Out:
# hello
# 30

# %%
dir()
# Out:
# ['In',
#  'NamespaceMagics',
#  'Out',
#  '_',
#  '_1',
#  '__',
#  '__K',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__import__',
#  '__ipywidgets',
#  '__loader__',
#  '__name__',
#  '__np',
#  '__package__',
#  '__pd',
#  '__pyspark',
#  '__session__',
#  '__spec__',
#  '__tf',
#  '__torch',
#  '__xr',
#  '_attempt_import',
#  '_check_imported',
#  '_dh',
#  '_i',
#  '_i1',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_jupyterlab_variableinspector_Jupyter',
#  '_jupyterlab_variableinspector_default',
#  '_jupyterlab_variableinspector_deletevariable',
#  '_jupyterlab_variableinspector_dict_list',
#  '_jupyterlab_variableinspector_displaywidget',
#  '_jupyterlab_variableinspector_getcontentof',
#  '_jupyterlab_variableinspector_getmatrixcontent',
#  '_jupyterlab_variableinspector_getshapeof',
#  '_jupyterlab_variableinspector_getsizeof',
#  '_jupyterlab_variableinspector_is_matrix',
#  '_jupyterlab_variableinspector_is_widget',
#  '_jupyterlab_variableinspector_nms',
# ...

# %%
# class decorator
class Decorator(object):
    def __init__(self, func):
        self.function = func

    def __call__(self, a, b):
        # original functionality
        result = self.function(a,b)
        # square
        return result**2

@Decorator
def add(a,b): #3,1
    return a+b

# add = Decorator(add)
add(1,2)
# Out:
# 9

# %%
class Decorator:
    def __init__(self, func):
        self.function = func

    def __call__(self, *args):
        try:
            if any([isinstance(i, str) for i in args]):  #[False, True, False]
                raise TypeError("Cannot pass string as arguments")
            else:
                return self.function(*args)
        except Exception as obj:
            print(obj)
            
def add(*args):
    sum1=0
    for num in args:
        sum1 = sum1+num
    return sum1

# print(add(10,20,30))
# print(add(10,'20',30))

add = Decorator(add)
add(10,'20',30)  #add.__call__()
add(10,20,30)
# Out:
# Cannot pass string as arguments
# 60

# %%
# magic methods - dunder methods
# 10 + 20 -> __add__ magic method, no need to call it explicitly, naming convention of magic method __magicmethodname__ (double underscore at starting and ending, not to use this rule for user defined function)
print(10+20)
print(add(10,20))
print((10).__add__(20))
# Out:
# 30
# 30
# 30

# %%
class Bank:
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')
 # instantiation:- creating an object ---> __init__ method will be running thoigh we are not explicitly calling __init__ ---> __init__ is magic method

# %%
# few examples of magic methods
# __init__(), __new__(), __str__(), __repr__(), __len__(), __call__(), __getitem__(), __setitem__(), __delitem__(), __contains__(), __iter__(), __add__(), __eq__(), __gt__()
# magic attributes - __all__, __module__, __bases__, __defaults__, __name__, __doc__, __dict__

# %%
# __init__() - constructor of class
class Bank:
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')

print("bank balance is:", b1.bank_balance)
b1.bank_balance = b1.bank_balance + 1000
print("bank balance is:", b1.bank_balance)
# Out:
# init is running
# bank balance is: 100
# bank balance is: 1100

# %%
# __dict__ - to see all class attributes with it's values
class Bank:
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')

print(b1.__dict__)
# Out:
# init is running
# {'bank_balance': 100, 'adhar': '8976 5678 9091', 'acc_no': 'IBH7890', 'customer_name': 'Koyel Pramanick'}

# %%
class Bank:
    '''This is the documentation'''
    bank_name = 'BOI'
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')

print(Bank.__dict__)
print(b1.__dict__)
# Out:
# init is running
# {'__module__': '__main__', '__doc__': 'This is the documentation', 'bank_name': 'BOI', '__init__': <function Bank.__init__ at 0x000002037CF1F7E0>, '__dict__': <attribute '__dict__' of 'Bank' objects>, '__weakref__': <attribute '__weakref__' of 'Bank' objects>}
# {'bank_balance': 100, 'adhar': '8976 5678 9091', 'acc_no': 'IBH7890', 'customer_name': 'Koyel Pramanick'}

# %%
# __new__ magic methid called automatically when new object is getting created, after that __init___ is getting called for assigning attributes in class objects

# %%
## __str__ - in Python __str__() magic method is a special method used to define a string representation of an object, used in prod for printing info of class object
class Bank:
    '''This is the documentation'''
    
    bank_name = 'BOI'
    
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

    def __str__(self):
        # return self.bank_balance #error as this is integer not a string
        # return self.acc_no # no error
        return "This is the object of bank class"

b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')

print(b1)
# Out:
# init is running
# This is the object of bank class

# %%
# __repr__ - magic method is a special method used to define a string representation of an object, used in development during debugging
# when both preset __repr__ and __str__, ony __str__ will be implemented

# %%
class Bank:
    '''This is the documentation'''
    
    bank_name = 'BOI'
    
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

    # def __repr__(self):
    #     return "this is from repr"

    # def __str__(self):
    #     # return self.bank_balance #error as this is integer not a string
    #     # return self.acc_no # no error
    #     return "This is the object of bank class, this string is coming from __str__"

    def __repr__(self):
        return "this is from repr"

b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')

print(b1)
# Out:
# init is running
# this is from repr

# %%
# __len__() - special method used to define length of an object
print(len([10,20,'i']))
# Out:
# 3

# %%
class Bank:
    '''This is the documentation'''
    
    bank_name = 'BOI'
    
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

    # def __repr__(self):
    #     return "this is from repr"

    # def __str__(self):
    #     # return self.bank_balance #error as this is integer not a string
    #     # return self.acc_no # no error
    #     return "This is the object of bank class, this string is coming from __str__"

    def __repr__(self):
        return "this is from repr"

    def __len__(self):
        return len(self.__dict__)

b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')
print(len(b1.__dict__))
print(len(b1))

del b1.acc_no
print(len(b1))
# Out:
# init is running
# 4
# 4
# 3

# %%
# __getitem__() - special method that enables instances of a class to be accessed using the indexing syntax ([])
class Bank:
    '''This is the documentation'''
    
    bank_name = 'BOI'
    
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

    # def __repr__(self):
    #     return "this is from repr"

    # def __str__(self):
    #     # return self.bank_balance #error as this is integer not a string
    #     # return self.acc_no # no error
    #     return "This is the object of bank class, this string is coming from __str__"

    def __repr__(self):
        return "this is from repr"

    def __len__(self):
        return len(self.__dict__)

    def __getitem__(self,key):
        return self.__dict__[key]

b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')
# print(b1[2]) # error
print(b1['acc_no'])
# Out:
# init is running
# IBH7890

# %%
data = [10, 20, 30, 40] # list --> __getitem__ method is getting called, access item of list
print(data[3])
# Out:
# 40

# %%
## __setitem__ - enables instances of a class to support assignment using the indexing syntax ([])
class Bank:
    '''This is the documentation'''
    
    bank_name = 'BOI'
    
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

    # def __repr__(self):
    #     return "this is from repr"

    # def __str__(self):
    #     # return self.bank_balance #error as this is integer not a string
    #     # return self.acc_no # no error
    #     return "This is the object of bank class, this string is coming from __str__"

    def __repr__(self):
        return "this is from repr"

    def __len__(self):
        return len(self.__dict__)

    def __getitem__(self,key):
        return self.__dict__[key]

    def __setitem__(self, instance_var, new_value):
        self.__dict__[instance_var] = new_value

b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')
print(b1.__dict__)
# print(b1[2]) # error
print(b1['acc_no'])
b1['bank_balance'] = 1000 # b1.__setitem__(self, instance_variable, new_value), same as dictionary key value - dictname[keyname] =  new_value - __setitem__(self, keyname, new_value)
# b1.acc_no = 1000
# print(b1['acc_no'], b1.acc_no)
print(b1.__dict__)
b1['bank_balance'] = b1['bank_balance'] + 1000
print(b1.__dict__)
# Out:
# init is running
# {'bank_balance': 100, 'adhar': '8976 5678 9091', 'acc_no': 'IBH7890', 'customer_name': 'Koyel Pramanick'}
# IBH7890
# {'bank_balance': 1000, 'adhar': '8976 5678 9091', 'acc_no': 'IBH7890', 'customer_name': 'Koyel Pramanick'}
# {'bank_balance': 2000, 'adhar': '8976 5678 9091', 'acc_no': 'IBH7890', 'customer_name': 'Koyel Pramanick'}

# %%
# __delitem__() - enables instances of a class to support delete of items ueing the del statements
class Bank:
    '''This is the documentation'''
    
    bank_name = 'BOI'
    
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

    # def __repr__(self):
    #     return "this is from repr"

    # def __str__(self):
    #     # return self.bank_balance #error as this is integer not a string
    #     # return self.acc_no # no error
    #     return "This is the object of bank class, this string is coming from __str__"

    def __repr__(self):
        return "this is from repr"

    def __len__(self):
        return len(self.__dict__)

    def __getitem__(self,key):
        return self.__dict__[key]

    def __setitem__(self, instance_var, new_value):
        self.__dict__[instance_var] = new_value

    def __delitem__(self, instance_var):
        del self.__dict__[instance_var]

b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')
print(b1.__dict__)
# print(b1[2]) # error
print(b1['acc_no'])
b1['bank_balance'] = 1000 # b1.__setitem__(self, instance_variable, new_value), same as dictionary key value - dictname[keyname] =  new_value - __setitem__(self, keyname, new_value)
# b1.acc_no = 1000
# print(b1['acc_no'], b1.acc_no)
print(b1.__dict__)
b1['bank_balance'] = b1['bank_balance'] + 1000
print(b1.__dict__)
# del b1.acc_no
del b1['bank_balance'] # __delitem__(self, instance_var)
print(b1.__dict__)
# Out:
# init is running
# {'bank_balance': 100, 'adhar': '8976 5678 9091', 'acc_no': 'IBH7890', 'customer_name': 'Koyel Pramanick'}
# IBH7890
# {'bank_balance': 1000, 'adhar': '8976 5678 9091', 'acc_no': 'IBH7890', 'customer_name': 'Koyel Pramanick'}
# {'bank_balance': 2000, 'adhar': '8976 5678 9091', 'acc_no': 'IBH7890', 'customer_name': 'Koyel Pramanick'}
# {'adhar': '8976 5678 9091', 'acc_no': 'IBH7890', 'customer_name': 'Koyel Pramanick'}

# %%
# __contains__ - enables instances of a class to support embership tesing using the in operator (membership operator)
class Bank:
    '''This is the documentation'''
    
    bank_name = 'BOI'
    
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

    # def __repr__(self):
    #     return "this is from repr"

    # def __str__(self):
    #     # return self.bank_balance #error as this is integer not a string
    #     # return self.acc_no # no error
    #     return "This is the object of bank class, this string is coming from __str__"

    def __repr__(self):
        return "this is from repr"

    def __len__(self):
        return len(self.__dict__)

    def __getitem__(self,key):
        return self.__dict__[key]

    def __setitem__(self, instance_var, new_value):
        self.__dict__[instance_var] = new_value

    def __delitem__(self, instance_var):
        del self.__dict__[instance_var]

    def __contains__(self, instance_var):
        return instance_var in self.__dict__

b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')
print(b1.__dict__)
# print(b1[2]) # error
print(b1['acc_no'])
b1['bank_balance'] = 1000 # b1.__setitem__(self, instance_variable, new_value), same as dictionary key value - dictname[keyname] =  new_value - __setitem__(self, keyname, new_value)
# b1.acc_no = 1000
# print(b1['acc_no'], b1.acc_no)
print(b1.__dict__)
b1['bank_balance'] = b1['bank_balance'] + 1000
print(b1.__dict__)
# del b1.acc_no
del b1['bank_balance'] # __delitem__(self, instance_var)
print(b1.__dict__)
print('bank_balance' in b1) # b1.__contains__(self, instance_var)
print('acc_no' in b1)
# Out:
# init is running
# {'bank_balance': 100, 'adhar': '8976 5678 9091', 'acc_no': 'IBH7890', 'customer_name': 'Koyel Pramanick'}
# IBH7890
# {'bank_balance': 1000, 'adhar': '8976 5678 9091', 'acc_no': 'IBH7890', 'customer_name': 'Koyel Pramanick'}
# {'bank_balance': 2000, 'adhar': '8976 5678 9091', 'acc_no': 'IBH7890', 'customer_name': 'Koyel Pramanick'}
# {'adhar': '8976 5678 9091', 'acc_no': 'IBH7890', 'customer_name': 'Koyel Pramanick'}
# False
# True

# %%
# __call__()
class Bank:
    '''This is the documentation'''
    
    bank_name = 'BOI'
    
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

    def __call__(self):
        print('code for calling object of a class')

b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')
b1()
# def display():
#     pass

# display()
# Out:
# init is running
# code for calling object of a class

# %%
# __iter__()

class Bank:
    '''This is the documentation'''
    
    bank_name = 'BOI'
    
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

    # def __iter__(self):
    #     pass
b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')
# for i i b1: #__iter__

# def display():
#     pass

# display()

# %%
# __add__()
# __eq__()
# __gt__()

print(10+20)
print((10).__add__(20))

print(10 == 20)
print((10).__eq__(20))

print(10>20)
print((10).__gt__(20))
# Out:
# 30
# 30
# False
# False
# False
# False

# %%
# magic attributes or built-in special attributes
# __module__ - name of the module in which the class was defined
class Bank:
    '''This is the documentation'''
    
    bank_name = 'BOI'
    
    def __init__(self, balance, adhar, acc_no, name):
        print("init is running")
        self.bank_balance = balance
        self.adhar = adhar
        self.acc_no = acc_no
        self.customer_name = name

    # def __iter__(self):
    #     pass
b1 = Bank(100, '8976 5678 9091', 'IBH7890', 'Koyel Pramanick')
print(b1.__module__)
# Out:
# init is running
# __main__

# %%
# class variables, class methods
class Employee:
    company_name = "infosys"
    def __init__(self, nm, sal):
        self.name = nm
        self.salary = sal

    def __getitem__(self, key):
        if key == "company_name":
            return self.__class__.company_name
        else:
            raise KeyError(f"Key {key} not found.")

    def __setitem__(self, key, new_value):
        if key == "company_name":
            self.__class__.company_name = new_value
        else:
            raise KeyError(f"Key {key} not found.")

e1 = Employee("jay", 30000)
e2 = Employee("vijay", 50000)
print(e1.__dict__)
print(e2.__dict__)
print(e1.__class__.__name__)
# print(e2.__class__.class_var)
# e1['']
e1['company_name'] = 'TCS'
print(e1['company_name'])
print(Employee.company_name)
Employee.company_name = 'Tulip'
print(e1['company_name'])
print(Employee.company_name)
# Out:
# {'name': 'jay', 'salary': 30000}
# {'name': 'vijay', 'salary': 50000}
# Employee
# TCS
# TCS
# Tulip
# Tulip

# %%
# self for object reference
# cls for class reference
# classmethod works for class variable
# add @classmethod decorator to make one method classmethod
# if @classmethod is not added, then function will work with objects only not the classname

class Employee:
    company_name = "infosys"
    def __init__(self, nm, sal):
        self.name = nm
        self.salary = sal
        
    @classmethod
    def get_company_name(cls):
        print(f'company name is: {cls.company_name}')

    @classmethod
    def change_company_name(cls):
        cls.company_name = 'TCS'
        print(f'company name after changing is: {cls.company_name}')

e1 = Employee("jay", 30000)
e2 = Employee("vijay", 50000)
print(Employee.company_name)
Employee.get_company_name()
e2.change_company_name()
print(Employee.company_name)
# Out:
# infosys
# company name is: infosys
# company name after changing is: TCS
# TCS

# %%
# setter and getter

# %%
class Bank:
    bank_name = 'BOI'
    rate_of_interest = 12.25

    @staticmethod
    def simple_interest(prin, n):
        si = (prin*n*r)/100
        print(si)

Bank.simple_interest(20000, 3)

# %%
class Employee:
    bonus = 2000
    def
    def display(self):
        print("Employee Class method")

class Manager:
    bonus1=5000
    def show(self):
        print("Manager Class method")

e1 = Employee()
m1 = Manager()


e1.display()
m1.show()
m1.bonus1
# Out:
# Employee Class method
# Manager Class method
# 5000

# %%
class Manager(Employee):
    bonus1 = 5000
    def show(self):
        print("Manager Class method")

e1 = Employee()
m1 = Manager()


e1.display()
m1.show()
m1.bonus
# Out:
# Employee Class method
# Manager Class method
# 2000

# %%
class Computer:
    def __init__(self):
        self.ram = '8gb'
        self.storage = '512gb'
        print("Computer class constructor called")

class Mobile(Computer):
    def __init__(self):
        self.model = 'iphone X'
        print("Mobile class constructor called")


App = Mobile()
print(App.__dict__)
# Out:
# Mobile class constructor called
# {'model': 'iphone X'}
