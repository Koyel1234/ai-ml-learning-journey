# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
# make data
x = np.array([5, 15, 25, 35, 45, 55]).reshape((-1,1))
y = np.array([5, 20, 14, 32, 22, 38])

# %%
print(x)
# Out:
# [[ 5]
#  [15]
#  [25]
#  [35]
#  [45]
#  [55]]

# %%
print(y)
# Out:
# [ 5 20 14 32 22 38]

# %%
#z = np.array([5, 15, 25, 35, 45, 55]).reshape((6,1))  #equivalent as reshape(-1,1)
#print(z)

# %%
# create a model and fit it
model = LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
# model = LinearRegression().fit(x, y)

# %%
r_sq = model.score(x, y)

# %%
print('Coefficient of Determination:',r_sq)
# Out:
# Coefficient of Determination: 0.715875613747954

# %%
print('intercept b0:',model.intercept_)
# Out:
# intercept b0: 5.633333333333329

# %%
print('coefficient b1', model.coef_)
# Out:
# coefficient b1 [0.54]

# %%
# y as more dimentional

new_model = LinearRegression().fit(x, y.reshape(-1,1))
print('intercept b0:', new_model.intercept_)
print('coefficient b1', new_model.coef_)
# Out:
# intercept b0: [5.63333333]
# coefficient b1 [[0.54]]

# %%
# predict response

y_pred = model.predict(x)
print('predicted response:',y_pred)
# Out:
# predicted response: [ 8.33333333 13.73333333 19.13333333 24.53333333 29.93333333 35.33333333]

# %% [markdown]
# # Simple Linear Regression - Krish Naik

# %% [markdown]
# #### Steps to follow:
# - Import some packages (numpy, pandas, sklearn, matplotlib)
# - Read the dataset
# - We need to split the data based on independent(x) and dependent(y) variables
# - Divide the complete dataset into training and testing dataset
# - Implement our classifier based on Simple Linear Regression
# - Implement the graph for Simple Linear Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Salary_Data.csv')

# %%
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
# divide the dataset into X and y
X=dataset.iloc[:,:-1]
y=dataset.iloc[:,1]

# %%
X.head()
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2

# %%
type(X.head())
# Out:
# pandas.core.frame.DataFrame

# %%
y.head()
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Salary, dtype: float64

# %%
type(y.head())
# Out:
# pandas.core.series.Series

# %%
X=dataset.iloc[:,:-1].values
y=dataset.iloc[:,1].values

# %%
X.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-ae5cd47bda90> in <module>
# ----> 1 X.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
# spliting the data based on training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=1/3,  random_state=0)

# %%
#implement our classifier based on simple linear regression
from sklearn.linear_model import LinearRegression

# %%
simpleLinearRegression = LinearRegression()

# %%
simpleLinearRegression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict=simpleLinearRegression.predict(X_test)

# %%
print(y_predict)
# Out:
# [ 40835.10590871 123079.39940819  65134.55626083  63265.36777221
#  115602.64545369 108125.8914992  116537.23969801  64199.96201652
#   76349.68719258 100649.1375447 ]

# %%
print(y_test)
# Out:
# [ 37731. 122391.  57081.  63218. 116969. 109431. 112635.  55794.  83088.
#  101302.]

# %%
print(X_test)
# Out:
# [[ 1.5]
#  [10.3]
#  [ 4.1]
#  [ 3.9]
#  [ 9.5]
#  [ 8.7]
#  [ 9.6]
#  [ 4. ]
#  [ 5.3]
#  [ 7.9]]

# %%
y_predict_somevalue=simpleLinearRegression.predict((11))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-56de71d79420> in <module>
# ----> 1 y_predict_somevalue=simpleLinearRegression.predict((11))
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     216         check_is_fitted(self)
#     217
# --> 218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...

# %%
y_predict_somevalue=simpleLinearRegression.predict([[11]])

# %%
y_predict_somevalue
# Out:
# array([129621.55911838])

# %%
y_predict_somevalue=simpleLinearRegression.predict((11).reshape(1,-1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-3def9ef945e8> in <module>
# ----> 1 y_predict_somevalue=simpleLinearRegression.predict((11).reshape(1,-1))
#
# AttributeError: 'int' object has no attribute 'reshape'

# %%
y_predict_somevalue=simpleLinearRegression.predict(np.array([10.5]).reshape(1,-1))

# %%
print(y_predict_somevalue)
print(dataset)
# Out:
# [124948.58789682]
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# ...

# %%
#implement the graph
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train,simpleLinearRegression.predict(X_train))
plt.show()

# %% [markdown]
# # Multiple Linear Regression - Krish Naik

# %%
#implementing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importing the dataset
dataset = pd.read_csv('50_Startups.csv')

# %%
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
X=dataset.iloc[:,:-1]
y=dataset.iloc[:,4]

# %%
#convert the columns into categorical columns
states=pd.get_dummies(X['State'],drop_first=True)

# %%
#drop the state column
X = X.drop('State',axis=1)

# %%
#concat the dummy variables
X=pd.concat([X,states],axis=1)

# %%
#spiliting the dataset into training set and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0)

# %%
#Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#fitting multiple linear regression to the training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#predicting the test set results
y_pred = regressor.predict(X_test)

# %%
#calculate r2
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)

# %%
print(score)
# Out:
# 0.9347068473282423

# %% [markdown]
# # Multicolinearity

# %%
import pandas as pd

# %%
import statsmodels.api as sm
df_adv = pd.read_csv('Advertising.csv', index_col=0)
X = df_adv[['TV','radio','newspaper']]
y = df_adv['sales']
df_adv.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
X = sm.add_constant(X)

# %%
X
# Out:
#      const     TV  radio  newspaper
# 1      1.0  230.1   37.8       69.2
# 2      1.0   44.5   39.3       45.1
# 3      1.0   17.2   45.9       69.3
# 4      1.0  151.5   41.3       58.5
# 5      1.0  180.8   10.8       58.4
# ..     ...    ...    ...        ...
# 196    1.0   38.2    3.7       13.8
# 197    1.0   94.2    4.9        8.1
# 198    1.0  177.0    9.3        6.4
# 199    1.0  283.6   42.0       66.2
# 200    1.0  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
#fit a ols model with intercept on TV and Radios
model = sm.OLS(y, X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Tue, 15 Jun 2021   Prob (F-statistic):           1.58e-96
# Time:                        11:21:38   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
import matplotlib.pyplot as plt

# %%
X.iloc[:,1:].corr()
# Out:
#                  TV     radio  newspaper
# TV         1.000000  0.054809   0.056648
# radio      0.054809  1.000000   0.354104
# newspaper  0.056648  0.354104   1.000000

# %%
df_salary = pd.read_csv('Salary_Data_Multicolinearity.csv')
df_salary.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
X = df_salary[['YearsExperience','Age']]
y = df_salary['Salary']

# %%
X = sm.add_constant(X)
X
# Out:
#     const  YearsExperience   Age
# 0     1.0              1.1  21.0
# 1     1.0              1.3  21.5
# 2     1.0              1.5  21.7
# 3     1.0              2.0  22.0
# 4     1.0              2.2  22.2
# 5     1.0              2.9  23.0
# 6     1.0              3.0  23.0
# 7     1.0              3.2  23.3
# 8     1.0              3.2  23.3
# 9     1.0              3.7  23.6
# 10    1.0              3.9  23.9
# 11    1.0              4.0  24.0
# 12    1.0              4.0  24.0
# 13    1.0              4.1  24.0
# 14    1.0              4.5  25.0
# 15    1.0              4.9  25.0
# 16    1.0              5.1  26.0
# 17    1.0              5.3  27.0
# 18    1.0              5.9  28.0
# 19    1.0              6.0  29.0
# 20    1.0              6.8  30.0
# 21    1.0              7.1  30.0
# 22    1.0              7.9  31.0
# 23    1.0              8.2  32.0
# 24    1.0              8.7  33.0
# 25    1.0              9.0  34.0
# 26    1.0              9.5  35.0
# ...

# %%
#fit a ols model with intercept on TV and Radios
model = sm.OLS(y, X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     323.9
# Date:                Tue, 15 Jun 2021   Prob (F-statistic):           1.35e-19
# Time:                        11:33:08   Log-Likelihood:                -300.35
# No. Observations:                  30   AIC:                             606.7
# Df Residuals:                      27   BIC:                             610.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
X.iloc[:,1:].corr()
# Out:
#                  YearsExperience       Age
# YearsExperience         1.000000  0.987258
# Age                     0.987258  1.000000
