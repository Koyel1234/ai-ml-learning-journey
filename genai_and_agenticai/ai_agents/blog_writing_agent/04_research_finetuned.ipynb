# %%
from __future__ import annotations

import operator
import os
import re
from datetime import date, datetime, timedelta
from pathlib import Path
from typing import TypedDict, List, Annotated, Literal, Optional

from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage
from dotenv import load_dotenv
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
load_dotenv()

# %%
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description = "one sentence describing what the reader should be able to do/understand after this section.",
        )
    
    bullets: List[str] = Field(
        ...,
        min_length = 3,
        max_length = 5,
        description = "3-5 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words : int = Field(
        ...,
        description = "Target word count for this section (120-550)."
    )
    
    tags: List[str] = Field(default_factory = list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False

# %%
class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str 
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"
    tasks: List[Task]

# %%
class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None   # prefer ISO "YYYY-MM-DD"
    snippet: Optional[str] = None
    source: Optional[str] = None

# %%
class Routerdecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    reason: str
    queries: List[str] = Field(default_factory = list)
    max_results_per_query: int = Field(5, description = "How many results to fetch per query (3-8).")

# %%
class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory = list)

# %%
class State(TypedDict):
    topic: str

    #routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Plan

    # NEW: recency control
    as_of: str           # ISO date, e.g. "2026-01-29"
    recency_days: int    # 7 for weekly news, 30 for hybrid, etc.
    
    # workers
    sections: Annotated[List[tuple[tuple, str]], operator.add]
    final: str

# %%
llm = ChatOpenAI(model = "gpt-4.1-mini")

# %%
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- If user asked for "last week/this week/latest", reflect that constraint IN THE QUERIES.
"""

def router_node(state: State) -> dict:
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}\nAs-of date: {state['as_of']}"),
        ]
    )

    # Set default recency window based on mode
    if decision.mode == "open_book":
        recency_days = 7
    elif decision.mode == "hybrid":
        recency_days = 45
    else:
        recency_days = 3650

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
        "recency_days": recency_days,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    """
    Uses TavilySearchResults if installed and TAVILY_API_KEY is set.
    Returns list of dict with common fields. Note: published date is often missing.
    """
    tool = TavilySearchResults(max_results = max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source")
            }
        )
    return normalized


def _iso_to_date(s: Optional[str]) -> Optional[date]:
    if not s:
        return None
    try:
        return date.fromisoformat(s[:10])
    except Exception:
        return None


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- If a published date is explicitly present in the result payload, keep it as YYYY-MM-DD.
  If missing or unclear, set published_at=null. Do NOT guess.
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:
    # take the first 10 queries from state
    queries = (state.get("queries", []) or [])[:10]
    max_results = 6

    raw_results: List[dict] = []

    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}
    
    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(
                content=(
                    f"As-of date: {state['as_of']}\n"
                    f"Recency days: {state['recency_days']}\n\n"
                    f"Raw results:\n{raw_results}"
                )
            ),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e
    evidence = list(dedup.values())

    # HARD RECENCY FILTER for open_book weekly roundup:
    # keep only items with a parseable ISO date and within the window.
    mode = state.get("mode", "closed_book")
    if mode == "open_book":
        as_of = date.fromisoformat(state["as_of"])
        cutoff = as_of - timedelta(days=int(state["recency_days"]))
        fresh: List[EvidenceItem] = []
        for e in evidence:
            d = _iso_to_date(e.published_at)
            if d and d >= cutoff:
                fresh.append(e)
        evidence = fresh

    return {"evidence": evidence}

# %%
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book:
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""



def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)
    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    # Force blog_kind for open_book
    forced_kind = "news_roundup" if mode == "open_book" else None

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {state['as_of']} (recency_days={state['recency_days']})\n"
                    f"{'Force blog_kind=news_roundup' if forced_kind else ''}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}\n\n"
                    f"Instruction: If mode=open_book, your plan must NOT drift into a tutorial."
                )
            ),
        ]
    )

    # Ensure open_book forces the kind even if model forgets
    if forced_kind:
        plan.blog_kind = "news_roundup"

    return {"plan": plan}

# %%
def fanout(state: State):
    assert state["plan"] is not None
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "as_of": state["as_of"],
                "recency_days": state["recency_days"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard:
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book:
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true:
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")
    as_of = payload.get("as_of")
    recency_days = payload.get("recency_days")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    # Provide a compact evidence list for citation use
    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {as_of} (recency_days={recency_days})\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    # deterministic ordering
    return {"sections": [(task.id, section_md)]}

# %%
def reducer_node(state: State) -> dict:
    plan = state["plan"]
    if plan is None:
        raise ValueError("Reducer called without a plan.")

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {plan.blog_title}\n\n{body}\n"

    filename = f"{plan.blog_title}.md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()
app

# %%
def run(topic: str, as_of: Optional[str] = None):
    if as_of is None:
        as_of = date.today().isoformat()

    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "as_of": as_of,
            "recency_days": 7,   # router may overwrite
            "sections": [],
            "final": "",
        }
    )

    plan: Plan = out["plan"]
    print("\n" + "=" * 100)
    print("TOPIC:", topic)
    print("AS_OF:", out.get("as_of"), "RECENCY_DAYS:", out.get("recency_days"))
    print("MODE:", out.get("mode"))
    print("BLOG_KIND:", plan.blog_kind)
    print("NEEDS_RESEARCH:", out.get("needs_research"))
    print("QUERIES:", (out.get("queries") or [])[:6])
    print("EVIDENCE_COUNT:", len(out.get("evidence", [])))
    if out.get("evidence"):
        print("EVIDENCE_SAMPLE:", [e.model_dump() for e in out["evidence"][:2]])
    print("TASKS:", len(plan.tasks))
    print("SAVED_MD_CHARS:", len(out.get("final", "")))
    print("=" * 100 + "\n")

    return out

# %%
run("Write a blog on Self Attention")
# Out:
# **** ['## Introduction to Self-Attention\n\nSelf-attention is a powerful mechanism in deep learning that allows models to weigh the importance of different parts of an input sequence when processing data. Unlike traditional methods that process words or tokens sequentially, self-attention enables a model to consider the entire sequence simultaneously, dynamically adjusting the focus to relevant elements at each step.\n\nIn the context of natural language processing (NLP), self-attention plays a critical role by helping models understand the relationships between words regardless of their position in a sentence. For example, in the sentence *"The cat that chased the mouse was hungry,"* self-attention allows the model to associate *"cat"* with *"was hungry"* even though they are separated by several words.\n\nThis capability has made self-attention the backbone of many state-of-the-art NLP architectures, especially Transformer models. By capturing long-range dependencies efficiently and enabling parallel processing, self-attention has revolutionized tasks like machine translation, text summarization, and question answering. Overall, it enhances the model’s understanding and generation of human language, marking a significant advancement in artificial intelligence.', '## How Self-Attention Works\n\nAt the core of self-attention lies the ability of a model to weigh the importance of different words in a sequence relative to each other, allowing it to capture context and relationships effectively. This mechanism involves three key components derived from the input embeddings: **queries (Q)**, **keys (K)**, and **values (V)**.\n\n1. **Creating Queries, Keys, and Values**  \n   Each word (or token) in the input sequence is first transformed into three vectors: a query vector, a key vector, and a value vector. These are typically generated by multiplying the input embedding with learned parameter matrices unique to each component.\n\n2. **Calculating Attention Scores**  \n   The attention score between a pair of tokens is obtained by computing the dot product between the query vector of one token and the key vector of another. This score represents how much focus should be placed on the other token when processing the current one. Mathematically, for each token, the attention scores with every other token are:\n\n   \\[\n   \\text{score}(Q_i, K_j) = Q_i \\cdot K_j^T\n   \\]\n\n3. **Scaling and Normalization**  \n   To prevent extremely large dot product values which can hinder training, the scores are scaled by the square root of the dimension of the key vectors:\n\n   \\[\n   \\text{scaled\\_score} = \\frac{\\text{score}(Q_i, K_j)}{\\sqrt{d_k}}\n   \\]\n\n   After scaling, the scores are passed through a softmax function to convert them into probabilities. This step normalizes the scores so they sum up to 1, emphasizing the most relevant tokens.\n\n4. **Weighted Sum of Values**  \n   Finally, each token’s representation is updated by computing a weighted sum of the value vectors, using the softmax probabilities as weights:\n\n   \\[\n   \\text{output}_i = \\sum_{j} \\alpha_{ij} V_j\n   \\]\n\n   Here, \\(\\alpha_{ij}\\) is the normalized attention score between token \\(i\\) and token \\(j\\).\n\nThis process allows the model to dynamically focus on different parts of the input sequence for each word, capturing complex dependencies and contextual information essential for natural language understanding tasks.', '## Self-Attention vs. Traditional Attention Mechanisms\n\nAttention mechanisms have revolutionized the field of natural language processing (NLP) by allowing models to focus selectively on different parts of input data when generating outputs. Traditional attention mechanisms, originally popularized in sequence-to-sequence models for tasks like machine translation, typically compute attention weights between the decoder’s current state and each encoder output. This helps the decoder to "attend" to relevant parts of the input  ...
# ### ## Introduction to Self-Attention
#
# Self-attention is a powerful mechanism in deep learning that allows models to weigh the importance of different parts of an input sequence when processing data. Unlike traditional methods that process words or tokens sequentially, self-attention enables a model to consider the entire sequence simultaneously, dynamically adjusting the focus to relevant elements at each step.
#
# In the context of natural language processing (NLP), self-attention plays a critical role by helping models understand the relationships between words regardless of their position in a sentence. For example, in the sentence *"The cat that chased the mouse was hungry,"* self-attention allows the model to associate *"cat"* with *"was hungry"* even though they are separated by several words.
#
# This capability has made self-attention the backbone of many state-of-the-art NLP architectures, especially Transformer models. By capturing long-range dependencies efficiently and enabling parallel processing, self-attention has revolutionized tasks like machine translation, text summarization, and question answering. Overall, it enhances the model’s understanding and generation of human language, marking a significant advancement in artificial intelligence.
#
# ## How Self-Attention Works
#
# At the core of self-attention lies the ability of a model to weigh the importance of different words in a sequence relative to each other, allowing it to capture context and relationships effectively. This mechanism involves three key components derived from the input embeddings: **queries (Q)**, **keys (K)**, and **values (V)**.
#
# 1. **Creating Queries, Keys, and Values**
#    Each word (or token) in the input sequence is first transformed into three vectors: a query vector, a key vector, and a value vector. These are typically generated by multiplying the input embedding with learned parameter matrices unique to each component.
#
# 2. **Calculating Attention Scores**
#    The attention score between a pair of tokens is obtained by computing the dot product between the query vector of one token and the key vector of another. This score represents how much focus should be placed on the other token when processing the current one. Mathematically, for each token, the attention scores with every other token are:
#
#    \[
#    \text{score}(Q_i, K_j) = Q_i \cdot K_j^T
#    \]
#
# 3. **Scaling and Normalization**
#    To prevent extremely large dot product values which can hinder training, the scores are scaled by the square root of the dimension of the key vectors:
#
#    \[
#    \text{scaled\_score} = \frac{\text{score}(Q_i, K_j)}{\sqrt{d_k}}
#    \]
#
#    After scaling, the scores are passed through a softmax function to convert them into probabilities. This step normalizes the scores so they sum up to 1, emphasizing the most relevant tokens.
#
# 4. **Weighted Sum of Values**
#    Finally, each token’s representation is updated by computing a weighted sum of the value vectors, using the softmax probabilities as weights:
#
#    \[
#    \text{output}_i = \sum_{j} \alpha_{ij} V_j
#    \]
#
#    Here, \(\alpha_{ij}\) is the normalized attention score between token \(i\) and token \(j\).
#
# This process allows the model to dynamically focus on different parts of the input sequence for each word, capturing complex dependencies and contextual information essential for natural language understanding tasks.
#
# ## Self-Attention vs. Traditional Attention Mechanisms
#
# Attention mechanisms have revolutionized the field of natural language processing (NLP) by allowing models to focus selectively on different parts of input data when generating outputs. Traditional attention mechanisms, originally popularized in sequence-to-sequence models for tasks like machine translation, typically compute attention weights between the decoder’s current state and each encoder output. This helps the decoder to "attend" to relevant parts of the input sequence, improving alignment and translation quality.
#
# **Traditional Attention Characteristics:**
#
# - **Cross-Attention Focus:** The attention is computed between two distinct sequences — for example, between the encoder outputs (source sequence) and decoder states (target sequence).
# - **Unidirectional Dependency:** Usually designed for mapping one sequence to another, not for capturing relationships within the same sequence.
# - **Limited Parallelism:** Since the decoder generates one token at a time and attends to all encoder states per step, parallel processing is constrained.
#
# In contrast, **self-attention** takes this concept a step further by relating elements _within the same sequence_. Every token attends simultaneously to all other tokens in the sequence, synthesizing rich contextual representations.
#
# **Key Advantages of Self-Attention:**
#
# - **Contextual Understanding:** Each token's representation is dynamically informed by the entire sequence, allowing nuanced interpretations of meaning depending on context.
# - **Parallelization:** Since attention can be computed simultaneously for all token positions, models can be trained much more efficiently, leveraging modern hardware.
# - **Long-Range Dependencies:** Self-attention effectively models relationships between distant tokens, overcoming limitations of recurrent architectures that struggle with long-range context.
# - **Simplicity and Scalability:** Self-attention forms the core of architectures like Transformers, which have scaled to massive models delivering state-of-the-art results in numerous NLP tasks.
#
# In summary, while traditional attention mechanisms enhance alignment between separate sequences, self-attention empowers models to holistically understand and represent the internal structure and dependencies of a single sequence. This innovation underpins the remarkable success of modern NLP architectures and has become a cornerstone of natural language understanding.
#
# ## Applications of Self-Attention in Models
#
# Self-attention is a fundamental mechanism that has revolutionized natural language processing by enabling models to weigh the importance of different words in a sequence dynamically. This capability has been effectively harnessed in several groundbreaking models, including Transformer, BERT, and GPT.
#
# ### Transformer
#
# The Transformer architecture, introduced by Vaswani et al. in 2017, was the first to showcase the power of self-attention as its core component. Unlike traditional recurrent neural networks (RNNs) that process data sequentially, the Transformer uses self-attention to capture relationships between all words in a sentence simultaneously. This allows the model to understand context more comprehensively and facilitates parallel processing, significantly speeding up training times. The Transformer’s multi-head self-attention mechanism enables it to focus on different parts of the input for each attention head, capturing diverse linguistic features and dependencies.
#
# ### BERT
#
# BERT (Bidirectional Encoder Representations from Transformers) leverages the Transformer’s self-attention layers to create deeply bidirectional representations of text. By attending to all positions in both directions (left and right context) simultaneously, BERT achieves a nuanced understanding of language context, which is critical for tasks such as question answering and sentiment analysis. Self-attention in BERT enables the model to capture complex dependencies regardless of their distance in the sequence, thereby improving the representation quality over traditional unidirectional models.
#
# ### GPT
#
# GPT (Generative Pre-trained Transformer), primarily designed for language generation, also uses self-attention but with a unidirectional (causal) constraint. This means that each word’s representation can only attend to previous words in the sequence, preserving the natural left-to-right text generation flow. The self-attention mechanism allows GPT to generate coherent and contextually relevant text by effectively modeling long-range dependencies and contextual cues, making it highly effective for tasks like text completion, summarization, and creative writing.
#
# In summary, self-attention is the backbone of these influential NLP models, enabling them to understand and generate human language with unprecedented accuracy and fluidity. Its ability to capture global context and relationships within text has made it a cornerstone in the design of modern language models.
#
# ## Advantages of Self-Attention
#
# Self-attention offers several key strengths that have made it the backbone of modern Natural Language Processing (NLP) models:
#
# - **Parallelization:** Unlike sequential models such as RNNs, self-attention enables the simultaneous processing of all tokens in a sequence. This parallel computation significantly speeds up training and inference, making it feasible to work with large datasets and complex models.
#
# - **Capturing Long-Range Dependencies:** Self-attention can directly relate each token in the input to every other token, regardless of their distance apart. This ability to model long-range dependencies is crucial for understanding context in long sentences or documents, where relevant information may be spread out.
#
# - **Scalability:** The self-attention mechanism scales gracefully with input size and model depth. By stacking multiple self-attention layers, models can build increasingly rich representations while maintaining manageable computational costs, especially when optimized with techniques like sparse attention or efficient approximations.
#
# These advantages collectively empower self-attention to excel in diverse NLP tasks, from language translation to text generation, leading to the widespread adoption of Transformer-based architectures.
#
# ## Challenges and Limitations
#
# While self-attention has revolutionized natural language processing (NLP) by enabling models to capture long-range dependencies effectively, it also comes with notable challenges and limitations.
#
# ### Computational Cost
#
# One of the primary drawbacks of self-attention mechanisms is their quadratic complexity with respect to the sequence length. Specifically, computing the attention scores requires calculating interactions between every pair of tokens in the input sequence, which leads to a computational cost of **O(n²)**. For very long sequences—such as long documents or paragraphs—this can result in significant memory usage and slower processing times, making it difficult to deploy self-attention-based models on resource-constrained devices or real-time applications.
#
# ### Scalability Issues
#
# Another challenge arises when scaling models to larger datasets or extending the sequence length. The quadratic growth in computation and memory demands limits the practicality of self-attention in domains like speech recognition, genome sequencing, or high-resolution vision tasks, where input sequences can be extremely large.
#
# ### Potential Solutions
#
# Researchers have proposed various strategies to mitigate these challenges:
#
# - **Sparse Attention Mechanisms:** Instead of attending to all tokens, sparse attention limits the attention scope to a subset of tokens, drastically reducing computation. Examples include fixed patterns (like local windows) or learned sparsity.
#
# - **Hierarchical and Long-Range Attention:** These techniques break down long sequences into smaller chunks or leverage hierarchical representations to attend across segments efficiently.
#
# - **Low-Rank Approximations:** Approaches such as Linformer or Performer approximate the full attention matrix with lower-rank structures, lowering the complexity from quadratic to linear or near-linear.
#
# - **Memory-Augmented Models:** Some architectures introduce external memory components to store and retrieve relevant information, reducing the need for extensive pairwise attention.
#
# By addressing these limitations, ongoing research continues to make self-attention more efficient and applicable to a wider range of real-world problems.
#
# ## Future Directions and Conclusion
#
# Self-attention has revolutionized natural language processing by enabling models to effectively capture contextual relationships within data. Its ability to weigh the importance of different tokens dynamically has laid the groundwork for powerful architectures like Transformers, which dominate today's NLP landscape.
#
# Looking ahead, research is focused on enhancing the efficiency and scalability of self-attention mechanisms. Techniques such as sparse attention, linear attention approximations, and memory-augmented models aim to reduce computational overhead while maintaining or improving performance. Additionally, expanding self-attention beyond text to modalities like vision, audio, and multimodal data is a burgeoning area, promising more unified and versatile AI systems.
#
# Moreover, integrating self-attention with advances in unsupervised learning and continual learning may further unlock the potential for models that are not only accurate but also adaptable and data-efficient. As self-attention continues to evolve, its role as a backbone component will likely extend beyond natural language processing to become a foundational element in broader AI research and applications.
# --- # Understanding Self-Attention: The Backbone of Modern NLP
#
# ## Introduction to Self-Attention
#
# Self-attention is a powerful mechanism in deep learning that allows models to weigh the importance of different parts of an input sequence when processing data. Unlike traditional methods that process words or tokens sequentially, self-attention enables a model to consider the entire sequence simultaneously, dynamically adjusting the focus to relevant elements at each step.
#
# In the context of natural language processing (NLP), self-attention plays a critical role by helping models understand the relationships between words regardless of their position in a sentence. For example, in the sentence *"The cat that chased the mouse was hungry,"* self-attention allows the model to associate *"cat"* with *"was hungry"* even though they are separated by several words.
#
# This capability has made self-attention the backbone of many state-of-the-art NLP architectures, especially Transformer models. By capturing long-range dependencies efficiently and enabling parallel processing, self-attention has revolutionized tasks like machine translation, text summarization, and question answering. Overall, it enhances the model’s understanding and generation of human language, marking a significant advancement in artificial intelligence.
#
# ## How Self-Attention Works
#
# At the core of self-attention lies the ability of a model to weigh the importance of different words in a sequence relative to each other, allowing it to capture context and relationships effectively. This mechanism involves three key components derived from the input embeddings: **queries (Q)**, **keys (K)**, and **values (V)**.
#
# 1. **Creating Queries, Keys, and Values**
#    Each word (or token) in the input sequence is first transformed into three vectors: a query vector, a key vector, and a value vector. These are typically generated by multiplying the input embedding with learned parameter matrices unique to each component.
#
# 2. **Calculating Attention Scores**
#    The attention score between a pair of tokens is obtained by computing the dot product between the query vector of one token and the key vector of another. This score represents how much focus should be placed on the other token when processing the current one. Mathematically, for each token, the attention scores with every other token are:
#
#    \[
#    \text{score}(Q_i, K_j) = Q_i \cdot K_j^T
#    \]
#
# 3. **Scaling and Normalization**
#    To prevent extremely large dot product values which can hinder training, the scores are scaled by the square root of the dimension of the key vectors:
#
#    \[
#    \text{scaled\_score} = \frac{\text{score}(Q_i, K_j)}{\sqrt{d_k}}
#    \]
#
#    After scaling, the scores are passed through a softmax function to convert them into probabilities. This step normalizes the scores so they sum up to 1, emphasizing the most relevant tokens.
#
# 4. **Weighted Sum of Values**
#    Finally, each token’s representation is updated by computing a weighted sum of the value vectors, using the softmax probabilities as weights:
#
#    \[
#    \text{output}_i = \sum_{j} \alpha_{ij} V_j
#    \]
#
#    Here, \(\alpha_{ij}\) is the normalized attention score between token \(i\) and token \(j\).
#
# This process allows the model to dynamically focus on different parts of the input sequence for each word, capturing complex dependencies and contextual information essential for natural language understanding tasks.
#
# ## Self-Attention vs. Traditional Attention Mechanisms
#
# Attention mechanisms have revolutionized the field of natural language processing (NLP) by allowing models to focus selectively on different parts of input data when generating outputs. Traditional attention mechanisms, originally popularized in sequence-to-sequence models for tasks like machine translation, typically compute attention weights between the decoder’s current state and each encoder output. This helps the decoder to "attend" to relevant parts of the input sequence, improving alignment and translation quality.
#
# **Traditional Attention Characteristics:**
#
# - **Cross-Attention Focus:** The attention is computed between two distinct sequences — for example, between the encoder outputs (source sequence) and decoder states (target sequence).
# - **Unidirectional Dependency:** Usually designed for mapping one sequence to another, not for capturing relationships within the same sequence.
# - **Limited Parallelism:** Since the decoder generates one token at a time and attends to all encoder states per step, parallel processing is constrained.
#
# In contrast, **self-attention** takes this concept a step further by relating elements _within the same sequence_. Every token attends simultaneously to all other tokens in the sequence, synthesizing rich contextual representations.
#
# **Key Advantages of Self-Attention:**
#
# - **Contextual Understanding:** Each token's representation is dynamically informed by the entire sequence, allowing nuanced interpretations of meaning depending on context.
# - **Parallelization:** Since attention can be computed simultaneously for all token positions, models can be trained much more efficiently, leveraging modern hardware.
# - **Long-Range Dependencies:** Self-attention effectively models relationships between distant tokens, overcoming limitations of recurrent architectures that struggle with long-range context.
# - **Simplicity and Scalability:** Self-attention forms the core of architectures like Transformers, which have scaled to massive models delivering state-of-the-art results in numerous NLP tasks.
#
# In summary, while traditional attention mechanisms enhance alignment between separate sequences, self-attention empowers models to holistically understand and represent the internal structure and dependencies of a single sequence. This innovation underpins the remarkable success of modern NLP architectures and has become a cornerstone of natural language understanding.
#
# ## Applications of Self-Attention in Models
#
# Self-attention is a fundamental mechanism that has revolutionized natural language processing by enabling models to weigh the importance of different words in a sequence dynamically. This capability has been effectively harnessed in several groundbreaking models, including Transformer, BERT, and GPT.
#
# ### Transformer
#
# The Transformer architecture, introduced by Vaswani et al. in 2017, was the first to showcase the power of self-attention as its core component. Unlike traditional recurrent neural networks (RNNs) that process data sequentially, the Transformer uses self-attention to capture relationships between all words in a sentence simultaneously. This allows the model to understand context more comprehensively and facilitates parallel processing, significantly speeding up training times. The Transformer’s multi-head self-attention mechanism enables it to focus on different parts of the input for each attention head, capturing diverse linguistic features and dependencies.
#
# ### BERT
#
# BERT (Bidirectional Encoder Representations from Transformers) leverages the Transformer’s self-attention layers to create deeply bidirectional representations of text. By attending to all positions in both directions (left and right context) simultaneously, BERT achieves a nuanced understanding of language context, which is critical for tasks such as question answering and sentiment analysis. Self-attention in BERT enables the model to capture complex dependencies regardless of their distance in the sequence, thereby improving the representation quality over traditional unidirectional models.
#
# ### GPT
#
# GPT (Generative Pre-trained Transformer), primarily designed for language generation, also uses self-attention but with a unidirectional (causal) constraint. This means that each word’s representation can only attend to previous words in the sequence, preserving the natural left-to-right text generation flow. The self-attention mechanism allows GPT to generate coherent and contextually relevant text by effectively modeling long-range dependencies and contextual cues, making it highly effective for tasks like text completion, summarization, and creative writing.
#
# In summary, self-attention is the backbone of these influential NLP models, enabling them to understand and generate human language with unprecedented accuracy and fluidity. Its ability to capture global context and relationships within text has made it a cornerstone in the design of modern language models.
#
# ## Advantages of Self-Attention
#
# Self-attention offers several key strengths that have made it the backbone of modern Natural Language Processing (NLP) models:
#
# - **Parallelization:** Unlike sequential models such as RNNs, self-attention enables the simultaneous processing of all tokens in a sequence. This parallel computation significantly speeds up training and inference, making it feasible to work with large datasets and complex models.
#
# - **Capturing Long-Range Dependencies:** Self-attention can directly relate each token in the input to every other token, regardless of their distance apart. This ability to model long-range dependencies is crucial for understanding context in long sentences or documents, where relevant information may be spread out.
#
# - **Scalability:** The self-attention mechanism scales gracefully with input size and model depth. By stacking multiple self-attention layers, models can build increasingly rich representations while maintaining manageable computational costs, especially when optimized with techniques like sparse attention or efficient approximations.
#
# These advantages collectively empower self-attention to excel in diverse NLP tasks, from language translation to text generation, leading to the widespread adoption of Transformer-based architectures.
#
# ## Challenges and Limitations
#
# While self-attention has revolutionized natural language processing (NLP) by enabling models to capture long-range dependencies effectively, it also comes with notable challenges and limitations.
#
# ### Computational Cost
#
# One of the primary drawbacks of self-attention mechanisms is their quadratic complexity with respect to the sequence length. Specifically, computing the attention scores requires calculating interactions between every pair of tokens in the input sequence, which leads to a computational cost of **O(n²)**. For very long sequences—such as long documents or paragraphs—this can result in significant memory usage and slower processing times, making it difficult to deploy self-attention-based models on resource-constrained devices or real-time applications.
#
# ### Scalability Issues
#
# Another challenge arises when scaling models to larger datasets or extending the sequence length. The quadratic growth in computation and memory demands limits the practicality of self-attention in domains like speech recognition, genome sequencing, or high-resolution vision tasks, where input sequences can be extremely large.
#
# ### Potential Solutions
#
# Researchers have proposed various strategies to mitigate these challenges:
#
# - **Sparse Attention Mechanisms:** Instead of attending to all tokens, sparse attention limits the attention scope to a subset of tokens, drastically reducing computation. Examples include fixed patterns (like local windows) or learned sparsity.
#
# - **Hierarchical and Long-Range Attention:** These techniques break down long sequences into smaller chunks or leverage hierarchical representations to attend across segments efficiently.
#
# - **Low-Rank Approximations:** Approaches such as Linformer or Performer approximate the full attention matrix with lower-rank structures, lowering the complexity from quadratic to linear or near-linear.
#
# - **Memory-Augmented Models:** Some architectures introduce external memory components to store and retrieve relevant information, reducing the need for extensive pairwise attention.
#
# By addressing these limitations, ongoing research continues to make self-attention more efficient and applicable to a wider range of real-world problems.
#
# ## Future Directions and Conclusion
#
# Self-attention has revolutionized natural language processing by enabling models to effectively capture contextual relationships within data. Its ability to weigh the importance of different tokens dynamically has laid the groundwork for powerful architectures like Transformers, which dominate today's NLP landscape.
#
# Looking ahead, research is focused on enhancing the efficiency and scalability of self-attention mechanisms. Techniques such as sparse attention, linear attention approximations, and memory-augmented models aim to reduce computational overhead while maintaining or improving performance. Additionally, expanding self-attention beyond text to modalities like vision, audio, and multimodal data is a burgeoning area, promising more unified and versatile AI systems.
#
# Moreover, integrating self-attention with advances in unsupervised learning and continual learning may further unlock the potential for models that are not only accurate but also adaptable and data-efficient. As self-attention continues to evolve, its role as a backbone component will likely extend beyond natural language processing to become a foundational element in broader AI research and applications.

# %%
out
# Out:
# {'topic': 'Write a blog on Self Attention',
#  'plan': Plan(blog_title='Understanding Self-Attention: The Backbone of Modern NLP', tasks=[Task(id=1, title='Introduction to Self-Attention', brief='Explain what self-attention is and why it is important in natural language processing and deep learning.'), Task(id=2, title='How Self-Attention Works', brief='Describe the mechanics of self-attention, including queries, keys, and values, and how attention scores are calculated.'), Task(id=3, title='Self-Attention vs. Traditional Attention Mechanisms', brief='Compare self-attention with classical attention mechanisms to highlight the unique benefits.'), Task(id=4, title='Applications of Self-Attention in Models', brief='Discuss how self-attention is utilized in popular models like Transformer, BERT, and GPT.'), Task(id=5, title='Advantages of Self-Attention', brief='Detail the strengths of self-attention such as parallelization, capturing long-range dependencies, and scalability.'), Task(id=6, title='Challenges and Limitations', brief='Explore some challenges self-attention faces including computational cost and potential solutions.'), Task(id=7, title='Future Directions and Conclusion', brief='Summarize key points and discuss future trends related to self-attention in AI research.')]),
#  'sections': ['## Introduction to Self-Attention\n\nSelf-attention is a powerful mechanism in deep learning that allows models to weigh the importance of different parts of an input sequence when processing data. Unlike traditional methods that process words or tokens sequentially, self-attention enables a model to consider the entire sequence simultaneously, dynamically adjusting the focus to relevant elements at each step.\n\nIn the context of natural language processing (NLP), self-attention plays a critical role by helping models understand the relationships between words regardless of their position in a sentence. For example, in the sentence *"The cat that chased the mouse was hungry,"* self-attention allows the model to associate *"cat"* with *"was hungry"* even though they are separated by several words.\n\nThis capability has made self-attention the backbone of many state-of-the-art NLP architectures, especially Transformer models. By capturing long-range dependencies efficiently and enabling parallel processing, self-attention has revolutionized tasks like machine translation, text summarization, and question answering. Overall, it enhances the model’s understanding and generation of human language, marking a significant advancement in artificial intelligence.',
#   '## How Self-Attention Works\n\nAt the core of self-attention lies the ability of a model to weigh the importance of different words in a sequence relative to each other, allowing it to capture context and relationships effectively. This mechanism involves three key components derived from the input embeddings: **queries (Q)**, **keys (K)**, and **values (V)**.\n\n1. **Creating Queries, Keys, and Values**  \n   Each word (or token) in the input sequence is first transformed into three vectors: a query vector, a key vector, and a value vector. These are typically generated by multiplying the input embedding with learned parameter matrices unique to each component.\n\n2. **Calculating Attention Scores**  \n   The attention score between a pair of tokens is obtained by computing the dot product between the query vector of one token and the key vector of another. This score represents how much focus should be placed on the other token when processing the current one. Mathematically, for each token, the attention scores with every other token are:\n\n   \\[\n   \\text{score}(Q_i, K_j) = Q_i \\cdot K_j^T\n   \\]\n\n3. **Scaling and Normalization**  \n   To prevent extremely large dot product values which can hinder training, the scores are scaled by the square root of the dimension of the key vectors:\n\n   \\[\n   \\text{scaled\\_score} = \\frac{\\text{score}(Q_i, K_j)}{\\sqrt{d_k}}\n   \\]\n\n   After scaling, the scores are passed through a softmax function to convert them into probabilities. This step normalizes the scores so they sum up to 1, emphasizing the most relevant tokens.\n\n4. **Weighted Sum of Values**  \n   Finally, each token’s representation is updated by computing a weighted sum of the value vectors, using the softmax probabilities as weights:\n\n   \\[\n   \\text{output}_i = \\sum_{j} \\alpha_{ij} V_j\n   \\]\n\n   Here, \\(\\alpha_{ij}\\) is the normalized attention score between token \\(i\\) and token \\(j\\).\n\nThis process allows the model to dynamically focus on different parts of the input sequence for each word, capturing complex dependencies and contextual information essential for natural language understanding tasks.',
#   '## Self-Attention vs. Traditional Attention Mechanisms\n\nAttention mechanisms have revolutionized the field of natural language processing (NLP) by allowing models to focus selectively on different parts of input data when generating outputs. Traditional attention mechanisms, originally popularized in sequence-to-sequence models for tasks like machine translation, typically compute attention weights between the decoder’s current state and each encoder output. This helps the decoder to "attend" to relevant parts of the input sequence, improving alignment and translation quality.\n\n**Traditional Attention Characteristics:**\n\n- **Cross-Attention Focus:** The attention is computed between two distinct sequences — for example, between the encoder outputs (source sequence) and decoder states (target sequence).\n- **Unidirectional Dependency:** Usually designed for mapping one sequence to another, not for capturing relationships within the same sequence.\n- **Limited Parallelism:** Since the decoder generates one token at a time and attends to all encoder states per step, parallel processing is constrained.\n\nIn contrast, **self-attention** takes this concept a step further by relating elements _within the same sequence_. Every token attends simultaneously to all other tokens in the sequence, synthesizing rich contextual representations.\n\n**Key Advantages of Self-Attention:**\n\n- **Contextual Understanding:** Each token\'s representation is dynamically informed by the entire sequence, allowing nuanced interpretations of meaning depending on context.\n- **Parallelization:** Since attention can be computed simultaneously for all token positions, models can be trained much more efficiently, leveraging modern hardware.\n- **Long-Range Dependencies:** Self-attention effectively models relationships between distant tokens, overcoming limitations of recurrent architectures that struggle with long-range context.\n- **Simplicity and Scalability:** Self-attention forms the core of architectures like Transformers, which have scaled to massive models delivering state-of-the-art results in numerous NLP tasks.\n\nIn summary, while traditional attention mechanisms enhance alignment between separate sequences, self-attention empowers models to holistically understand and represent the internal structure and dependencies of a single sequence. This innovation underpins the remarkable success of modern NLP architectures and has become a cornerstone of natural language understanding.',
#   '## Applications of Self-Attention in Models\n\nSelf-attention is a fundamental mechanism that has revolutionized natural language processing by enabling models to weigh the importance of different words in a sequence dynamically. This capability has been effectively harnessed in several groundbreaking models, including Transformer, BERT, and GPT.\n\n### Transformer\n\nThe Transformer architecture, introduced by Vaswani et al. in 2017, was the first to showcase the power of self-attention as its core component. Unlike traditional recurrent neural networks (RNNs) that process data sequentially, the Transformer uses self-attention to capture relationships between all words in a sentence simultaneously. This allows the model to understand context more comprehensively and facilitates parallel processing, significantly speeding up training times. The Transformer’s multi-head self-attention mechanism enables it to focus on different parts of the input for each attention head, capturing diverse linguistic features and dependencies.\n\n### BERT\n\nBERT (Bidirectional Encoder Representations from Transformers) leverages the Transformer’s self-attention layers to create deeply bidirectional representations of text. By attending to all positions in both directions (left and right context) simultaneously, BERT achieves a nuanced understanding of language context, which is critical for tasks such as question answering and sentiment analysis. Self-attention in BERT enables the model to capture complex dependencies regardless of their distance in the sequence, thereby improving the representation quality over traditional unidirectional models.\n\n### GPT\n\nGPT (Generative Pre-trained Transformer), primarily designed for language generation, also uses self-attention but with a unidirectional (causal) constraint. This means that each word’s representation can only attend to previous words in the sequence, preserving the natural left-to-right text generation flow. The self-attention mechanism allows GPT to generate coherent and contextually relevant text by effectively modeling long-range dependencies and contextual cues, making it highly effective for tasks like text completion, summarization, and creative writing.\n\nIn summary, self-attention is the backbone of these influential NLP models, enabling them to understand and generate human language with unprecedented accuracy and fluidity. Its ability to capture global context and relationships within text has made it a cornerstone in the design of modern language models.',
#   '## Advantages of Self-Attention\n\nSelf-attention offers several key strengths that have made it the backbone of modern Natural Language Processing (NLP) models:\n\n- **Parallelization:** Unlike sequential models such as RNNs, self-attention enables the simultaneous processing of all tokens in a sequence. This parallel computation significantly speeds up training and inference, making it feasible to work with large datasets and complex models.\n\n- **Capturing Long-Range Dependencies:** Self-attention can directly relate each token in the input to every other token, regardless of their distance apart. This ability to model long-range dependencies is crucial for understanding context in long sentences or documents, where relevant information may be spread out.\n\n- **Scalability:** The self-attention mechanism scales gracefully with input size and model depth. By stacking multiple self-attention layers, models can build increasingly rich representations while maintaining manageable computational costs, especially when optimized with techniques like sparse attention or efficient approximations.\n\nThese advantages collectively empower self-attention to excel in diverse NLP tasks, from language translation to text generation, leading to the widespread adoption of Transformer-based architectures.',
#   '## Challenges and Limitations\n\nWhile self-attention has revolutionized natural language processing (NLP) by enabling models to capture long-range dependencies effectively, it also comes with notable challenges and limitations.\n\n### Computational Cost\n\nOne of the primary drawbacks of self-attention mechanisms is their quadratic complexity with respect to the sequence length. Specifically, computing the attention scores requires calculating interactions between every pair of tokens in the input sequence, which leads to a computational cost of **O(n²)**. For very long sequences—such as long documents or paragraphs—this can result in significant memory usage and slower processing times, making it difficult to deploy self-attention-based models on resource-constrained devices or real-time applications.\n\n### Scalability Issues\n\nAnother challenge arises when scaling models to larger datasets or extending the sequence length. The quadratic growth in computation and memory demands limits the practicality of self-attention in domains like speech recognition, genome sequencing, or high-resolution vision tasks, where input sequences can be extremely large.\n\n### Potential Solutions\n\nResearchers have proposed various strategies to mitigate these challenges:\n\n- **Sparse Attention Mechanisms:** Instead of attending to all tokens, sparse attention limits the attention scope to a subset of tokens, drastically reducing computation. Examples include fixed patterns (like local windows) or learned sparsity.\n\n- **Hierarchical and Long-Range Attention:** These techniques break down long sequences into smaller chunks or leverage hierarchical representations to attend across segments efficiently.\n\n- **Low-Rank Approximations:** Approaches such as Linformer or Performer approximate the full attention matrix with lower-rank structures, lowering the complexity from quadratic to linear or near-linear.\n\n- **Memory-Augmented Models:** Some architectures introduce external memory components to store and retrieve relevant information, reducing the need for extensive pairwise attention.\n\nBy addressing these limitations, ongoing research continues to make self-attention more efficient and applicable to a wider range of real-world problems.',
#   "## Future Directions and Conclusion\n\nSelf-attention has revolutionized natural language processing by enabling models to effectively capture contextual relationships within data. Its ability to weigh the importance of different tokens dynamically has laid the groundwork for powerful architectures like Transformers, which dominate today's NLP landscape.\n\nLooking ahead, research is focused on enhancing the efficiency and scalability of self-attention mechanisms. Techniques such as sparse attention, linear attention approximations, and memory-augmented models aim to reduce computational overhead while maintaining or improving performance. Additionally, expanding self-attention beyond text to modalities like vision, audio, and multimodal data is a burgeoning area, promising more unified and versatile AI systems.\n\nMoreover, integrating self-attention with advances in unsupervised learning and continual learning may further unlock the potential for models that are not only accurate but also adaptable and data-efficient. As self-attention continues to evolve, its role as a backbone component will likely extend beyond natural language processing to become a foundational element in broader AI research and applications."],
#  'final': '# Understanding Self-Attention: The Backbone of Modern NLP\n\n## Introduction to Self-Attention\n\nSelf-attention is a powerful mechanism in deep learning that allows models to weigh the importance of different parts of an input sequence when processing data. Unlike traditional methods that process words or tokens sequentially, self-attention enables a model to consider the entire sequence simultaneously, dynamically adjusting the focus to relevant elements at each step.\n\nIn the context of natural language processing (NLP), self-attention plays a critical role by helping models understand the relationships between words regardless of their position in a sentence. For example, in the sentence *"The cat that chased the mouse was hungry,"* self-attention allows the model to associate *"cat"* with *"was hungry"* even though they are separated by several words.\n\nThis capability has made self-attention the backbone of many state-of-the-art NLP architectures, especially Transformer models. By capturing long-range dependencies efficiently and enabling parallel processing, self-attention has revolutionized tasks like machine translation, text summarization, and question answering. Overall, it enhances the model’s understanding and generation of human language, marking a significant advancement in artificial intelligence.\n\n## How Self-Attention Works\n\nAt the core of self-attention lies the ability of a model to weigh the importance of different words in a sequence relative to each other, allowing it to capture context and relationships effectively. This mechanism involves three key components derived from the input embeddings: **queries (Q)**, **keys (K)**, and **values (V)**.\n\n1. **Creating Queries, Keys, and Values**  \n   Each word (or token) in the input sequence is first transformed into three vectors: a query vector, a key vector, and a value vector. These are typically generated by multiplying the input embedding with learned parameter matrices unique to each component.\n\n2. **Calculating Attention Scores**  \n   The attention score between a pair of tokens is obtained by computing the dot product between the query vector of one token and the key vector of another. This score represents how much focus should be placed on the other token when processing the current one. Mathematically, for each token, the attention scores with every other token are:\n\n   \\[\n   \\text{score}(Q_i, K_j) = Q_i \\cdot K_j^T\n   \\]\n\n3. **Scaling and Normalization**  \n   To prevent extremely large dot product values which can hinder training, the scores are scaled by the square root of the dimension of the key vectors:\n\n   \\[\n   \\text{scaled\\_score} = \\frac{\\text{score}(Q_i, K_j)}{\\sqrt{d_k}}\n   \\]\n\n   After scaling, the scores are passed through a softmax function to convert them into probabilities. This step normalizes the scores so they sum up to 1, emphasizing the most relevant tokens.\n\n4. **Weighted Sum of Values**  \n   Finally, each token’s representation is updated by computing a weighted sum of the value vectors, using the softmax probabilities as weights:\n\n   \\[\n   \\text{output}_i = \\sum_{j} \\alpha_{ij} V_j\n   \\]\n\n   Here, \\(\\alpha_{ij}\\) is the normalized attention score between token \\(i\\) and token \\(j\\).\n\nThis process allows the model to dynamically focus on different parts of the input sequence for each word, capturing complex dependencies and contextual information essential for natural language understanding tasks.\n\n## Self-Attention vs. Traditional Attention Mechanisms\n\nAttention mechanisms have revolutionized the field of natural language processing (NLP) by allowing models to focus selectively on different parts of input data when generating outputs. Traditional attention mechanisms, originally popularized in sequence-to-sequence models for tasks like machine translation, typically compute attention weights between the decoder’s current state and each encoder output.  ...
