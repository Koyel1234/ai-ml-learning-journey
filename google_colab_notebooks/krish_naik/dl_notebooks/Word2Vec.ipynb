# %% [markdown]
# <a href="https://colab.research.google.com/github/Koyel1234/ai-ml-learning-journey/blob/main/google_colab_notebooks/krish_naik/dl_notebooks/Word2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=9c7bcd9e5e14baf23af75b7559d90b17d365abad94fb1e9c62cd512155fec630
#   Stored in directory: /root/.cache/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# ...

# %%
# !wget -c "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz"
# Out:
# --2025-05-15 16:53:33--  https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 16.182.64.72, 52.216.217.112, 52.216.52.120, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|16.182.64.72|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-05-15 16:53:33 ERROR 404: Not Found.

# %%
model = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary = True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-c63c6bab9cd8> in <cell line: 0>()
# ----> 1 model = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary = True)
#
# /usr/local/lib/python3.11/dist-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1717
#    1718         """
# -> 1719         return _load_word2vec_format(
#    1720             cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
#    1721             limit=limit, datatype=datatype, no_header=no_header,
#
# /usr/local/lib/python3.11/dist-packages/gensim/models/keyedvectors.py in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header, binary_chunk_size)
#    2046
# ...
