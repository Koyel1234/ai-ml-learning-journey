# %% [markdown]
# <a href="https://colab.research.google.com/github/Koyel1234/ai-ml-learning-journey/blob/main/google_colab_notebooks/data_load_in_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import csv
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5f8e584e-c0dc-4c29-b390-dad29be9d529" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f8e584e-c0dc-4c29-b390-dad29be9d529">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving neighbor-districts.json to neighbor-districts.json

# %%
data = next(iter(uploaded.values()))

# %%
d = json.loads(data.decode())

# %%
print(d)
# Out:
# {'lahul_and_spiti/Q837595': ['leh_district/Q1921210', 'kinnaur/Q1862950', 'chamba/Q1060614', 'kangra/Q727232', 'kishtwar/Q2321899', 'kargil_district/Q1650798', 'kullu/Q2980880'], 'kinnaur/Q1862950': ['kullu/Q2980880', 'lahul_and_spiti/Q837595', 'uttarkashi/Q1773437', 'shimla/Q1921404'], 'kullu/Q2980880': ['shimla/Q1921404', 'lahul_and_spiti/Q837595', 'kinnaur/Q1862950', 'kangra/Q727232', 'mandi/Q1892161'], 'chamba/Q1060614': ['lahul_and_spiti/Q837595', 'kangra/Q727232', 'kishtwar/Q2321899', 'pathankot/Q172269', 'doda/Q2298979', 'kathua/Q2375700'], 'kangra/Q727232': ['hoshiarpur/Q304800', 'lahul_and_spiti/Q837595', 'chamba/Q1060614', 'una/Q2301741', 'gurdaspur/Q146708', 'pathankot/Q172269', 'kullu/Q2980880', 'mandi/Q1892161', 'hamirpur/Q2086180'], 'leh_district/Q1921210': ['lahul_and_spiti/Q837595', 'kargil_district/Q1650798'], 'kargil_district/Q1650798': ['anantnag/Q2982349', 'leh_district/Q1921210', 'lahul_and_spiti/Q837595', 'kishtwar/Q2321899', 'ganderbal/Q2556028', 'bandipora/Q29
# ...

# %%
import io
import pandas as pd

# %%
#df = pd.read_json(io.StringIO(uploaded.get('neighbor-districts.json').decode('utf-8')))

# %%
with open('neighbor-districts.json') as f:
  data = json.load(f)

# %%
data
# Out:
# {'adilabad/Q15211': ['komram_bheem/Q28170184',
#   'nanded/Q692389',
#   'yavatmal/Q1804852',
#   'nirmal/Q28169750',
#   'chandrapur/Q1797274'],
#  'agar_malwa/Q15732396': ['rajgarh/Q1833306',
#   'shajapur/Q2449803',
#   'ratlam/Q2299164',
#   'ujjain/Q892641',
#   'jhalawar/Q1471417'],
#  'agra/Q606343': ['etawah/Q1815288',
#   'hathras/Q1814892',
#   'dhaulpur/Q1207709',
#   'bhind/Q2341700',
#   'morena/Q2341467',
#   'mathura/Q1773422',
#   'etah/Q1773429',
#   'firozabad/Q1946950',
#   'bharatpur/Q854861'],
#  'ahmedabad_district/Q401686': ['anand_district/Q485683',
#   'mahesana_district/Q2019694',
#   'botad_district/Q14505072',
#   'surendranagar_district/Q237535',
#   'bhavnagar_district/Q854963',
#   'gandhinagar_district/Q1772860',
#   'kheda_district/Q1755463'],
#  'ahmednagar/Q401744': ['nashik/Q1797269',
#   'konkan_division/Q6268840',
#   'pune_district/Q1797336',
#   'bid/Q814037',
#   'osmanabad/Q1647186',
#   'aurangabad/Q592942',
#   'thane/Q943099',
# ...

# %%
len(data)
# Out:
# 723

# %%
type(data)
# Out:
# dict

# %%
for i in data.items:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-530534baf62e> in <module>()
# ----> 1 for i in data.items:
#       2     print(i)
#
# TypeError: 'builtin_function_or_method' object is not iterable
